# %% [markdown]
# ## Métodos para objetos de tipo string en Pandas
#
# El dataset utilizado contiene el ``nombre``, ``departamento``y ``salario``de cada empleado que hay en el sector público de la ciudad de Chicago (actualizado a 2024).
#
# Más contexto puede encontrarse en [Kaggle](https://www.kaggle.com/datasets/chicago/chicago-citywide-payroll-data) o en el siguiente [link](https://data.cityofchicago.org/Administration-Finance/Current-Employee-Names-Salaries-and-Position-Title/xzkq-xp2w/about_data).

# %%
import pandas as pd
import os

# %%
# importación de datos
data_path = '../Datasets/'
filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath)
df.head(5)
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department Full or Part-Time  \
# 0            BOARD OF ELECTION COMMISSIONERS                 F
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH                 F
# 2         DEPARTMENT OF PROCUREMENT SERVICES                 F
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES                 F
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION                 F
#
#   Salary or Hourly  Typical Hours  Annual Salary  Hourly Rate
# 0           SALARY            NaN        34176.0          NaN
# 1           SALARY            NaN        71004.0          NaN
# 2           SALARY            NaN        90660.0          NaN
# 3           SALARY            NaN        71004.0          NaN
# 4           SALARY            NaN        46056.0          NaN

# %% [markdown]
# No todas las columnas nos interesan, podemos omitir horas típicas y hourly rate.

# %%
filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath, usecols=["Name","Job Titles","Department","Annual Salary"])
df.head(5)
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31932 entries, 0 to 31931
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           31932 non-null  object
#  1   Job Titles     31932 non-null  object
#  2   Department     31932 non-null  object
#  3   Annual Salary  24795 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 998.0+ KB

# %%
df.shape
# Out:
# (31932, 4)

# %%
# Podemos crear un dataframe que contenga el número de valores nulos de este dataset

df.isna().sum().to_frame().head(10)
# Out:
#                   0
# Name              0
# Job Titles        0
# Department        0
# Annual Salary  7137

# %% [markdown]
# **Recordar los métodos dropna para eliminar valores nulos (DataFramesI).**

# %%
df_filtered = df.dropna(how='any') # si alguna entrada es nan, no se toma en cuenta
df_filtered
# Out:
#                         Name                        Job Titles  \
# 0      GARCIA, CHRISTOPHER A           CLERK - BD OF ELECTIONS
# 1              SILVA, JAVIER                     PROJECT COORD
# 2         HARRISON, LETECHIA         SR PROCUREMENT SPECIALIST
# 3        WASHINGTON, MAURICE                     PROJECT COORD
# 4       ASHFORD, MARQUISHA D                  INQUIRY AIDE III
# ...                      ...                               ...
# 31924       SYAS, VICTORIA M                     PARAMEDIC I/C
# 31925      COOGAN, PATRICK M                    LIEUTENANT-EMT
# 31927     DE LA ROSA, JOSEPH                 FIRE ENGINEER-EMT
# 31929         GRADILLA, IVON  SUPERVISING TRAFFIC CONTROL AIDE
# 31931      POWELL, TIMOTHY M          CHIEF OPERATING ENGINEER
#
#                                               Department  Annual Salary
# 0                        BOARD OF ELECTION COMMISSIONERS       34176.00
# 1                    CHICAGO DEPARTMENT OF PUBLIC HEALTH       71004.00
# 2                     DEPARTMENT OF PROCUREMENT SERVICES       90660.00
# 3              DEPARTMENT OF FAMILY AND SUPPORT SERVICES       71004.00
# 4                 OFFICE OF PUBLIC SAFETY ADMINISTRATION       46056.00
# ...                                                  ...            ...
# 31924                            CHICAGO FIRE DEPARTMENT      101052.00
# 31925                            CHICAGO FIRE DEPARTMENT      135144.00
# 31927                            CHICAGO FIRE DEPARTMENT      118830.00
# 31929  OFFICE OF EMERGENCY MANAGEMENT AND COMMUNICATIONS       74844.00
# 31931        DEPARTMENT OF FLEET AND FACILITY MANAGEMENT      143228.76
#
# [24795 rows x 4 columns]

# %%
# también podemos utilizar este método desde la importación de datos

filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath, usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df.head(5)
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0

# %% [markdown]
# ## Métodos string típicos
#
# * Las Series de Pandas tienen un atributo ``str`` que expone un objeto a métodos de string, que ya hemos visto.
# * La mayoría de estos métodos son similares a los de python (ejemplo, upper, lower, title)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24795 entries, 0 to 31931
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           24795 non-null  object
#  1   Job Titles     24795 non-null  object
#  2   Department     24795 non-null  object
#  3   Annual Salary  24795 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 968.6+ KB

# %%
# podemos cambiar el tipo de objeto de la columna Departament

df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24795 entries, 0 to 31931
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           24795 non-null  object
#  1   Job Titles     24795 non-null  category
#  2   Department     24795 non-null  category
#  3   Annual Salary  24795 non-null  float64
# dtypes: category(2), float64(1), object(1)
# memory usage: 695.4+ KB

# %%
df['Job Titles'].str.lower()
# Out:
# 0                 clerk - bd of elections
# 1                           project coord
# 2               sr procurement specialist
# 3                           project coord
# 4                        inquiry aide iii
#                        ...
# 31924                       paramedic i/c
# 31925                      lieutenant-emt
# 31927                   fire engineer-emt
# 31929    supervising traffic control aide
# 31931            chief operating engineer
# Name: Job Titles, Length: 24795, dtype: object

# %%
df['Job Titles'].str.upper()
# Out:
# 0                 CLERK - BD OF ELECTIONS
# 1                           PROJECT COORD
# 2               SR PROCUREMENT SPECIALIST
# 3                           PROJECT COORD
# 4                        INQUIRY AIDE III
#                        ...
# 31924                       PARAMEDIC I/C
# 31925                      LIEUTENANT-EMT
# 31927                   FIRE ENGINEER-EMT
# 31929    SUPERVISING TRAFFIC CONTROL AIDE
# 31931            CHIEF OPERATING ENGINEER
# Name: Job Titles, Length: 24795, dtype: object

# %%
df['Job Titles'].str.title()
# Out:
# 0                 Clerk - Bd Of Elections
# 1                           Project Coord
# 2               Sr Procurement Specialist
# 3                           Project Coord
# 4                        Inquiry Aide Iii
#                        ...
# 31924                       Paramedic I/C
# 31925                      Lieutenant-Emt
# 31927                   Fire Engineer-Emt
# 31929    Supervising Traffic Control Aide
# 31931            Chief Operating Engineer
# Name: Job Titles, Length: 24795, dtype: object

# %%
df['Job Titles'].str.len()
# Out:
# 0        23
# 1        13
# 2        25
# 3        13
# 4        16
#          ..
# 31924    13
# 31925    14
# 31927    17
# 31929    32
# 31931    24
# Name: Job Titles, Length: 24795, dtype: int64

# %%
df['Job Titles'].str.title().str.len()
# Out:
# 0        23
# 1        13
# 2        25
# 3        13
# 4        16
#          ..
# 31924    13
# 31925    14
# 31927    17
# 31929    32
# 31931    24
# Name: Job Titles, Length: 24795, dtype: int64

# %%
df['Job Titles'].str.split('-')
# Out:
# 0                [CLERK ,  BD OF ELECTIONS]
# 1                           [PROJECT COORD]
# 2               [SR PROCUREMENT SPECIALIST]
# 3                           [PROJECT COORD]
# 4                        [INQUIRY AIDE III]
#                         ...
# 31924                       [PARAMEDIC I/C]
# 31925                     [LIEUTENANT, EMT]
# 31927                  [FIRE ENGINEER, EMT]
# 31929    [SUPERVISING TRAFFIC CONTROL AIDE]
# 31931            [CHIEF OPERATING ENGINEER]
# Name: Job Titles, Length: 24795, dtype: object

# %% [markdown]
# ## Filtrado con métodos string

# %%
filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath,
                 usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")

df.head(5)
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0

# %%
is_water = df["Job Titles"].str.lower().str.contains("water")
is_water
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31924    False
# 31925    False
# 31927    False
# 31929    False
# 31931    False
# Name: Job Titles, Length: 24795, dtype: bool

# %%
# método contains checa si un string está contenido en algún lugar de la columna
# Esto regresa una serie de True, False, así que hay que incluirlo como condición

is_water = df["Job Titles"].str.lower().str.contains("water")
df[is_water]
# Out:
#                       Name                            Job Titles  \
# 519       MACIEL, SANDRA M               WATER QUALITY INSPECTOR
# 2210        BOYCE, ADNER L                     WATER CHEMIST III
# 2304       O NEAL, ROZELLA           SUPVSR OF WATER RATE TAKERS
# 2734    GALLAGHER, MICHAEL        SAFETY SPECIALIST - WATER MGMT
# 2890       BOLTON, BRIAN E                  WATER METER ASSESSOR
# ...                    ...                                   ...
# 21458   HUYNH, ALEXANDER T  MANAGING ENGINEER - WATER MANAGEMENT
# 21591       THOME, JAMES A             ASST SUPT OF WATER METERS
# 21627  MCFARLAND, ANDREW S  MANAGING ENGINEER - WATER MANAGEMENT
# 21793      KRUEGER, ANGELA        ASST ENGINEER OF WATER PUMPING
# 21913       WALLER, JOHN A          GEN SUPT OF WATER MANAGEMENT
#
#                            Department  Annual Salary
# 519    DEPARTMENT OF WATER MANAGEMENT        77424.0
# 2210   DEPARTMENT OF WATER MANAGEMENT       112020.0
# 2304   DEPARTMENT OF WATER MANAGEMENT       135120.0
# 2734   DEPARTMENT OF WATER MANAGEMENT       112224.0
# 2890   DEPARTMENT OF WATER MANAGEMENT       112212.0
# ...                               ...            ...
# 21458  DEPARTMENT OF WATER MANAGEMENT       136404.0
# 21591  DEPARTMENT OF WATER MANAGEMENT       115488.0
# 21627  DEPARTMENT OF WATER MANAGEMENT       136404.0
# 21793  DEPARTMENT OF WATER MANAGEMENT       140544.0
# 21913  DEPARTMENT OF WATER MANAGEMENT       139056.0
#
# [81 rows x 4 columns]

# %%
starts_civil = df["Job Titles"].str.lower().str.startswith("civil")
df[starts_civil]
# Out:
#                           Name          Job Titles  \
# 445          GONZALEZ, ALONDRA  CIVIL ENGINEER III
# 799               LUKE, STEFAN   CIVIL ENGINEER IV
# 1818           BALTSAS, JOHN M  CIVIL ENGINEER III
# 1834            PATEL, MAYUR J   CIVIL ENGINEER IV
# 2073           HAMEIRI, AVIKAM    CIVIL ENGINEER V
# ...                        ...                 ...
# 19622           ALSUFY, ASEM S   CIVIL ENGINEER II
# 19636           TRUONG, MINH Q   CIVIL ENGINEER IV
# 20611       CROCKER, MATTHEW L    CIVIL ENGINEER V
# 21716         ARUNA, REMIGIJUS    CIVIL ENGINEER V
# 28282  BECQ GIRAUDON, EMILIE F    CIVIL ENGINEER V
#
#                                  Department  Annual Salary
# 445    CHICAGO DEPARTMENT OF TRANSPORTATION        84972.0
# 799    CHICAGO DEPARTMENT OF TRANSPORTATION        93708.0
# 1818         DEPARTMENT OF WATER MANAGEMENT       122196.0
# 1834   CHICAGO DEPARTMENT OF TRANSPORTATION       115872.0
# 2073                DEPARTMENT OF BUILDINGS       145872.0
# ...                                     ...            ...
# 19622        DEPARTMENT OF WATER MANAGEMENT        79368.0
# 19636        DEPARTMENT OF WATER MANAGEMENT       101448.0
# 20611  CHICAGO DEPARTMENT OF TRANSPORTATION       106080.0
# 21716        DEPARTMENT OF WATER MANAGEMENT       117792.0
# 28282  CHICAGO DEPARTMENT OF TRANSPORTATION       145872.0
#
# [63 rows x 4 columns]

# %%
ends_iv = df["Job Titles"].str.lower().str.endswith("iv")
df[ends_iv]
# Out:
#                     Name              Job Titles  \
# 799         LUKE, STEFAN       CIVIL ENGINEER IV
# 1207     JONES, YASMIN Y            LIBRARIAN IV
# 1811   GLADNEY, ANGELA M                CLERK IV
# 1832      BANNA, FEDAA N  ELECTRICAL ENGINEER IV
# 1834      PATEL, MAYUR J       CIVIL ENGINEER IV
# ...                  ...                     ...
# 20828     KEITH, YOLANDA                CLERK IV
# 24531   SUAREZ, MIGUEL A                CLERK IV
# 29015   ESQUIVEL, ANNA B  PUBLIC HEALTH NURSE IV
# 29468    AIKENS, CLORA M  PUBLIC HEALTH NURSE IV
# 31491  CAINE, JAN NITA D  PUBLIC HEALTH NURSE IV
#
#                                  Department  Annual Salary
# 799    CHICAGO DEPARTMENT OF TRANSPORTATION        93708.0
# 1207                 CHICAGO PUBLIC LIBRARY        91884.0
# 1811              CHICAGO POLICE DEPARTMENT        84972.0
# 1832         CHICAGO DEPARTMENT OF AVIATION       133428.0
# 1834   CHICAGO DEPARTMENT OF TRANSPORTATION       115872.0
# ...                                     ...            ...
# 20828   CHICAGO DEPARTMENT OF PUBLIC HEALTH        48960.0
# 24531        CHICAGO DEPARTMENT OF AVIATION        48960.0
# 29015   CHICAGO DEPARTMENT OF PUBLIC HEALTH       107328.0
# 29468   CHICAGO DEPARTMENT OF PUBLIC HEALTH       118428.0
# 31491   CHICAGO DEPARTMENT OF PUBLIC HEALTH       118428.0
#
# [233 rows x 4 columns]

# %% [markdown]
# ## Métodos str para índices y Columnas

# %%
# hacemos importación de datos y utilizamos el nombre del empleado como index

filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath, index_col="Name",
                 usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")

df.head(5)
# Out:
#                                       Job Titles  \
# Name
# GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# SILVA, JAVIER                      PROJECT COORD
# HARRISON, LETECHIA     SR PROCUREMENT SPECIALIST
# WASHINGTON, MAURICE                PROJECT COORD
# ASHFORD, MARQUISHA D            INQUIRY AIDE III
#
#                                                       Department  \
# Name
# GARCIA, CHRISTOPHER A            BOARD OF ELECTION COMMISSIONERS
# SILVA, JAVIER                CHICAGO DEPARTMENT OF PUBLIC HEALTH
# HARRISON, LETECHIA            DEPARTMENT OF PROCUREMENT SERVICES
# WASHINGTON, MAURICE    DEPARTMENT OF FAMILY AND SUPPORT SERVICES
# ASHFORD, MARQUISHA D      OFFICE OF PUBLIC SAFETY ADMINISTRATION
#
#                        Annual Salary
# Name
# GARCIA, CHRISTOPHER A        34176.0
# SILVA, JAVIER                71004.0
# HARRISON, LETECHIA           90660.0
# WASHINGTON, MAURICE          71004.0
# ASHFORD, MARQUISHA D         46056.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24795 entries, GARCIA, CHRISTOPHER A to POWELL, TIMOTHY M
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Job Titles     24795 non-null  category
#  1   Department     24795 non-null  category
#  2   Annual Salary  24795 non-null  float64
# dtypes: category(2), float64(1)
# memory usage: 501.6+ KB

# %%
df.index.str.strip().str.title()
# Out:
# Index(['Garcia, Christopher A', 'Silva, Javier', 'Harrison, Letechia',
#        'Washington, Maurice', 'Ashford, Marquisha D', 'Flynn, Shanika',
#        'Mathis, Desiree', 'Mack, Qiana S', 'Guzman, Melissa M',
#        'Perez, William B',
#        ...
#        'Serb, Steven J', 'Pellegrini, Nicholas R', 'Oliva, Christina',
#        'Brown, Thomas M', 'Lovell, Amy M', 'Syas, Victoria M',
#        'Coogan, Patrick M', 'De La Rosa, Joseph', 'Gradilla, Ivon',
#        'Powell, Timothy M'],
#       dtype='object', name='Name', length=24795)

# %%
df.index.str.strip().str.upper()
# Out:
# Index(['GARCIA, CHRISTOPHER A', 'SILVA, JAVIER', 'HARRISON, LETECHIA',
#        'WASHINGTON, MAURICE', 'ASHFORD, MARQUISHA D', 'FLYNN, SHANIKA',
#        'MATHIS, DESIREE', 'MACK, QIANA S', 'GUZMAN, MELISSA M',
#        'PEREZ, WILLIAM B',
#        ...
#        'SERB, STEVEN J', 'PELLEGRINI, NICHOLAS R', 'OLIVA, CHRISTINA',
#        'BROWN, THOMAS M', 'LOVELL, AMY M', 'SYAS, VICTORIA M',
#        'COOGAN, PATRICK M', 'DE LA ROSA, JOSEPH', 'GRADILLA, IVON',
#        'POWELL, TIMOTHY M'],
#       dtype='object', name='Name', length=24795)

# %% [markdown]
# ## Método split
#
# * el método ``str.get``accesa a un elemento de la lista por su índice

# %%
filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath, index_col="Name",
                 usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")

df.head(5)
# Out:
#                                       Job Titles  \
# Name
# GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# SILVA, JAVIER                      PROJECT COORD
# HARRISON, LETECHIA     SR PROCUREMENT SPECIALIST
# WASHINGTON, MAURICE                PROJECT COORD
# ASHFORD, MARQUISHA D            INQUIRY AIDE III
#
#                                                       Department  \
# Name
# GARCIA, CHRISTOPHER A            BOARD OF ELECTION COMMISSIONERS
# SILVA, JAVIER                CHICAGO DEPARTMENT OF PUBLIC HEALTH
# HARRISON, LETECHIA            DEPARTMENT OF PROCUREMENT SERVICES
# WASHINGTON, MAURICE    DEPARTMENT OF FAMILY AND SUPPORT SERVICES
# ASHFORD, MARQUISHA D      OFFICE OF PUBLIC SAFETY ADMINISTRATION
#
#                        Annual Salary
# Name
# GARCIA, CHRISTOPHER A        34176.0
# SILVA, JAVIER                71004.0
# HARRISON, LETECHIA           90660.0
# WASHINGTON, MAURICE          71004.0
# ASHFORD, MARQUISHA D         46056.0

# %%
df['Job Titles'].str.split(" ") # crea listas
# Out:
# Name
# GARCIA, CHRISTOPHER A            [CLERK, -, BD, OF, ELECTIONS]
# SILVA, JAVIER                                 [PROJECT, COORD]
# HARRISON, LETECHIA               [SR, PROCUREMENT, SPECIALIST]
# WASHINGTON, MAURICE                           [PROJECT, COORD]
# ASHFORD, MARQUISHA D                      [INQUIRY, AIDE, III]
#                                          ...
# SYAS, VICTORIA M                              [PARAMEDIC, I/C]
# COOGAN, PATRICK M                             [LIEUTENANT-EMT]
# DE LA ROSA, JOSEPH                        [FIRE, ENGINEER-EMT]
# GRADILLA, IVON           [SUPERVISING, TRAFFIC, CONTROL, AIDE]
# POWELL, TIMOTHY M                 [CHIEF, OPERATING, ENGINEER]
# Name: Job Titles, Length: 24795, dtype: object

# %%
# nos quedamos con el primer elemento de esta lista
df['Job Titles'].str.split(" ").str.get(0)
# Out:
# Name
# GARCIA, CHRISTOPHER A             CLERK
# SILVA, JAVIER                   PROJECT
# HARRISON, LETECHIA                   SR
# WASHINGTON, MAURICE             PROJECT
# ASHFORD, MARQUISHA D            INQUIRY
#                               ...
# SYAS, VICTORIA M              PARAMEDIC
# COOGAN, PATRICK M        LIEUTENANT-EMT
# DE LA ROSA, JOSEPH                 FIRE
# GRADILLA, IVON              SUPERVISING
# POWELL, TIMOTHY M                 CHIEF
# Name: Job Titles, Length: 24795, dtype: object

# %%
# podemos hacer estadística de estos valores
df['Job Titles'].str.split(" ").str.get(0).value_counts()
# Out:
# Job Titles
# POLICE                 10458
# FIREFIGHTER-EMT         2147
# SERGEANT                1262
# PARAMEDIC                704
# FIRE                     563
#                        ...
# INFRASTRUCTURE             1
# FUEL                       1
# INTAKE                     1
# COMMANDER-LOGISTICS        1
# COMMANDER-PARAMEDIC        1
# Name: count, Length: 293, dtype: int64

# %%
# podríamos por ejemplo encontrar el primer nombre más común

filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath,
                 usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")
df.head()
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0

# %%
df["Name"].str.split(", ").str.slice(start=0,stop=1,step=1)
# Out:
# 0            [GARCIA]
# 1             [SILVA]
# 2          [HARRISON]
# 3        [WASHINGTON]
# 4           [ASHFORD]
#              ...
# 31924          [SYAS]
# 31925        [COOGAN]
# 31927    [DE LA ROSA]
# 31929      [GRADILLA]
# 31931        [POWELL]
# Name: Name, Length: 24795, dtype: object

# %%
lista = [1,2,3,4,5]
lista[0:2]
# Out:
# [1, 2]

# %%
df["Name"].str.title().str.split(", ").str.get(1).str.strip().str.split(" ").str.get(0).value_counts()
# Out:
# Name
# Michael    734
# John       456
# Daniel     397
# Joseph     343
# David      339
#           ...
# Padraic      1
# Saadeh       1
# Camron       1
# Skyeler      1
# Derec        1
# Name: count, Length: 5138, dtype: int64

# %% [markdown]
# ### Parámetro expand del método split
# * El parámetro ``expand``permite regresar un dataframe en lugar de una Serie de listas dentro de un split.

# %%
filename = 'Chicago_employee_salaries.csv' 
fullpath = os.path.join(data_path, filename)

df = pd.read_csv(filepath_or_buffer=fullpath,
                 usecols=["Name","Job Titles","Department","Annual Salary"]).dropna(how='any')
df['Department'] = df['Department'].astype("category")
df['Job Titles'] = df['Job Titles'].astype("category")
df.head()
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0

# %%
# podemos separar entre primer nombre y apellido y crear nuevas columnas

df[["Apellido","Nombre"]] = df["Name"].str.split(",", expand=True)

# %%
df.head(5)
# Out:
#                     Name                 Job Titles  \
# 0  GARCIA, CHRISTOPHER A    CLERK - BD OF ELECTIONS
# 1          SILVA, JAVIER              PROJECT COORD
# 2     HARRISON, LETECHIA  SR PROCUREMENT SPECIALIST
# 3    WASHINGTON, MAURICE              PROJECT COORD
# 4   ASHFORD, MARQUISHA D           INQUIRY AIDE III
#
#                                   Department  Annual Salary    Apellido  \
# 0            BOARD OF ELECTION COMMISSIONERS        34176.0      GARCIA
# 1        CHICAGO DEPARTMENT OF PUBLIC HEALTH        71004.0       SILVA
# 2         DEPARTMENT OF PROCUREMENT SERVICES        90660.0    HARRISON
# 3  DEPARTMENT OF FAMILY AND SUPPORT SERVICES        71004.0  WASHINGTON
# 4     OFFICE OF PUBLIC SAFETY ADMINISTRATION        46056.0     ASHFORD
#
#            Nombre
# 0   CHRISTOPHER A
# 1          JAVIER
# 2        LETECHIA
# 3         MAURICE
# 4     MARQUISHA D

# %% [markdown]
# ## Ejemplos

# %%
filename='netflix_titles.csv'
fullpath = os.path.join(data_path,filename)

df_netflix = pd.read_csv(fullpath)
df_netflix.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_netflix["cast"].dropna().str.split(', ').values.tolist()
# Out:
# [['Ama Qamata',
#   'Khosi Ngema',
#   'Gail Mabalane',
#   'Thabang Molaba',
#   'Dillon Windvogel',
#   'Natasha Thahane',
#   'Arno Greeff',
#   'Xolile Tshabalala',
#   'Getmore Sithole',
#   'Cindy Mahlangu',
#   'Ryle De Morny',
#   'Greteli Fincham',
#   'Sello Maake Ka-Ncube',
#   'Odwa Gwanya',
#   'Mekaila Mathys',
#   'Sandi Schultz',
#   'Duane Williams',
#   'Shamilla Miller',
#   'Patrick Mofokeng'],
#  ['Sami Bouajila',
#   'Tracy Gotoas',
#   'Samuel Jouy',
#   'Nabiha Akkari',
#   'Sofia Lesaffre',
#   'Salim Kechiouche',
#   'Noureddine Farihi',
#   'Geert Van Rampelberg',
#   'Bakary Diombera'],
#  ['Mayur More',
#   'Jitendra Kumar',
#   'Ranjan Raj',
#   'Alam Khan',
#   'Ahsaas Channa',
#   'Revathi Pillai',
#   'Urvi Singh',
#   'Arun Kumar'],
#  ['Kate Siegel',
#   'Zach Gilford',
#   'Hamish Linklater',
#   'Henry Thomas',
#   'Kristin Lehman',
#   'Samantha Sloyan',
#   'Igby Rigney',
#   'Rahul Kohli',
#   'Annarah Cymone',
#   'Annabeth Gish',
#   'Alex Essoe',
#   'Rahul Abburi',
#   'Matt Biedel',
#   'Michael Trucco',
#   'Crystal Balint',
#   'Louis Oliver'],
#  ['Vanessa Hudgens',
#   'Kimiko Glenn',
#   'James Marsden',
#   'Sofia Carson',
#   'Liza Koshy',
#   'Ken Jeong',
#   'Elizabeth Perkins',
#   'Jane Krakowski',
#   'Michael McKean',
#   'Phil LaMarr'],
#  ['Kofi Ghanaba',
#   'Oyafunmike Ogunlano',
#   'Alexandra Duah',
#   'Nick Medley',
#   'Mutabaruka',
#   'Afemo Omilami',
#   'Reggie Carter',
#   'Mzuri'],
#  ['Mel Giedroyc', 'Sue Perkins', 'Mary Berry', 'Paul Hollywood'],
#  ['Melissa McCarthy',
#   "Chris O'Dowd",
#   'Kevin Kline',
#   'Timothy Olyphant',
#   'Daveed Diggs',
#   'Skyler Gisondo',
#   'Laura Harrier',
#   'Rosalind Chao',
#   'Kimberly Quinn',
#   'Loretta Devine',
#   'Ravi Kapoor'],
#  ['Sukollawat Kanarot',
#   'Sushar Manaying',
#   'Pavarit Mongkolpisit',
#   'Sahajak Boonthanakit',
#   'Suthipongse Thatphithakkul',
#   'Bhasaworn Bawronkirati',
#   'Daweerit Chullasapya',
#   'Waratthaya Wongchayaporn',
#   'Kittiphoom Wongpentak',
#   'Abhicha Thanachanun',
#   'Nophand Boonyai',
#   'Kittipong Khamsat',
#   'Arisara Wongchalee',
#   'Jaytiya Naiwattanakul',
#   'Pantipa Arunwattanachai',
#   'Panupan Jantanawong',
#   'Kungtap Saelim',
#   'Phumphat Chartsuriyakiat',
#   'Issara Veranitinunt',
#   'Keerati Sivakuae',
#   'Panjai Sirisuwan',
#   'Supranee Charoenpol',
#   'Suda Chuenban',
#   'Visaka Banhansupavat',
#   'Pitchatorn Santinatornkul'],
#  ['Luna Wedler',
#   'Jannis Niewöhner',
#   'Milan Peschel',
#   'Edin Hasanović',
#   'Anna Fialová',
#   'Marlon Boess',
#   'Victor Boccard',
#   'Fleur Geffrier',
#   'Aziz Dyab',
#   'Mélanie Fouché',
#   'Elizaveta Maximová'],
#  ['Klara Castanho',
#   'Lucca Picon',
#   'Júlia Gomes',
#   'Marcus Bessa',
#   'Kiria Malheiros',
#   'Fernanda Concon',
#   'Gabriel Lima',
#   'Caio Cabral',
#   'Leonardo Cidade',
#   'Jade Cardozo'],
#  ['Logan Browning',
#   'Brandon P. Bell',
#   'DeRon Horton',
#   'Antoinette Robertson',
#   'John Patrick Amedori',
#   'Ashley Blaine Featherson',
#   'Marque Richardson',
#   'Giancarlo Esposito'],
#  ['Luis Ernesto Franco',
#   'Camila Sodi',
#   'Sergio Goyri',
#   'Samadhi Zendejas',
#   'Eduardo Yáñez',
#   'Sonya Smith',
#   'Alejandro Camacho',
#   'Azela Robinson',
#   'Uriel del Toro',
#   'Géraldine Bazán',
#   'Gabriela Roel',
#   'Marcus Ornellas'],
#  ['Freida Pinto',
#   'Logan Marshall-Green',
#   'Robert John Burke',
#   'Megan Elisabeth Kelly',
#   'Sarah Minnich',
#   'Hayes Hargrove',
#   'Mark Sivertsen',
#   'Brandon Fierro',
#   'Antonio Valles',
#   'Clint Obenchain'],
#  ['Blanca Suárez',
#   'Iván Marcos',
#   'Óscar Casas',
#   'Adrián Lastra',
#   'Francesc Garrido',
#   'Stefan Weinert',
#   'Julia Möller',
#   'Alicia Chojnowski'],
#  ['Engin Altan Düzyatan',
#   'Serdar Gökhan',
#   'Hülya Darcan',
#   'Kaan Taşaner',
#   'Esra Bilgiç',
#   'Osman Soykut',
#   'Serdar Deniz',
#   'Cengiz Coşkun',
#   'Reshad Strik',
#   'Hande Subaşı'],
#  ['Kamal Hassan',
#   'Meena',
#   'Gemini Ganesan',
#   'Heera Rajgopal',
#   'Nassar',
#   'S.P. Balasubrahmanyam'],
#  ['Maisie Benson', 'Paul Killam', 'Kerry Gudjohnsen', 'AC Lim'],
#  ['Prashanth', 'Aishwarya Rai Bachchan', 'Sri Lakshmi', 'Nassar'],
#  ['Brooke Satchwell'],
#  ['Arvind Swamy',
#   'Kajol',
#   'Prabhu Deva',
#   'Nassar',
#   'S.P. Balasubrahmanyam',
#   'Girish Karnad'],
#  ['Adam Sandler',
#   'Kevin James',
#   'Chris Rock',
#   'David Spade',
#   'Rob Schneider',
#   'Salma Hayek',
#   'Maria Bello',
#   'Maya Rudolph',
#   'Colin Quinn',
#   'Tim Meadows',
#   'Joyce Van Patten'],
#  ['Keri Russell',
#   'Josh Hamilton',
#   'J.K. Simmons',
#   'Dakota Goyo',
#   'Kadan Rockett',
#   'L.J. Benet',
#   'Rich Hutchman',
#   'Myndy Crist',
#   'Annie Thurman',
#   'Jake Brennan'],
#  ['Liam Hemsworth',
#   'Gary Oldman',
#   'Amber Heard',
#   'Harrison Ford',
#   'Lucas Till',
#   'Embeth Davidtz',
#   'Julian McMahon',
#   'Josh Holloway',
#   'Richard Dreyfuss',
#   'Angela Sarafyan'],
#  ['Abhishek Banerjee',
#   'Rinku Rajguru',
#   'Delzad Hiwale',
#   'Kunal Kapoor',
#   'Zoya Hussain',
#   'Nikhil Dwivedi',
#   'Palomi Ghosh'],
#  ['Lauren Ash',
#   "Rory O'Malley",
#   'RuPaul Charles',
#   'Jill Talley',
#   'Ike Barinholtz',
#   'Jon Barinholtz',
#   'Matthew Craig',
#   'Bob Odenkirk',
#   'Mike Hagerty',
#   'Katie Rich',
#   'Chris Witaske'],
#  ['Asa Butterfield',
#   'Gillian Anderson',
#   'Ncuti Gatwa',
#   'Emma Mackey',
#   'Connor Swindells',
#   'Kedar Williams-Stirling',
#   'Alistair Petrie'],
#  ['Lee Jung-jae',
#   'Park Hae-soo',
#   'Wi Ha-jun',
#   'Oh Young-soo',
#   'Jung Ho-yeon',
#   'Heo Sung-tae',
#   'Kim Joo-ryoung',
#   'Tripathi Anupam',
#   'You Seong-joo',
#   'Lee You-mi'],
#  ['Dami Lee',
#   'Jason Lee',
#   'Bommie Catherine Han',
#   'Jennifer Waescher',
#   'Nancy Kim'],
#  ['Adrian Titieni',
#   'Elena Purea',
#   'Judith State',
#   'Valeriu Andriuță',
#   'Tudor Smoleanu',
#   'Virgil Aioanei',
#   'Radu Botar',
#   'Petronela Grigorescu',
#   'Bogdan Nechifor',
#   'Cristian Bota'],
#  ['Gilles Lellouche',
#   'Karim Leklou',
#   'François Civil',
#   'Adèle Exarchopoulos',
#   'Kenza Fortas',
#   'Cyril Lecomte',
#   'Michaël Abiteboul',
#   'Idir Azougli',
#   'Vincent Darmuzey',
#   'Jean-Yves Berteloot'],
#  ['Antti Pääkkönen',
#   'Heljä Heikkinen',
#   'Lynne Guaglione',
#   'Pasi Ruohonen',
#   'Rauno Ahonen'],
#  ['Billy Magnussen',
#   'Ron Yuan',
#   'Qu Jingjing',
#   'Terry Chen',
#   'Vanness Wu',
#   'Jin Xing',
#   'Philip Ng',
#   'Xia Yu',
#   'Yu Xia'],
#  ['Vatsal Dubey',
#   'Julie Tejwani',
#   'Rupa Bhimani',
#   'Jigna Bhardwaj',
#   'Rajesh Kava',
#   'Mousam',
#   'Swapnil'],
#  ['Yuri Lowenthal',
#   'Kimberly Brooks',
#   'Antony Del Rio',
#   'Trevor Devall',
#   'Ben Diskin',
#   'Grey Griffin',
#   'David Kaye',
#   'Tom Kenny',
#   'Judy Alice Lee',
#   'Roger Craig Smith',
#   'Fred Tatasciore'],
#  ['Roy Scheider',
#   'Robert Shaw',
#   'Richard Dreyfuss',
#   'Lorraine Gary',
#   'Murray Hamilton',
#   'Carl Gottlieb',
#   'Jeffrey Kramer',
#   'Susan Backlinie',
#   'Jonathan Filley',
#   'Ted Grossman'],
#  ['Roy Scheider',
#   'Lorraine Gary',
#   'Murray Hamilton',
#   'Joseph Mascolo',
#   'Jeffrey Kramer',
#   'Collin Wilcox Paxton',
#   'Ann Dusenberry',
#   'Mark Gruner',
#   'Barry Coe',
#   'Susan French'],
#  ['Dennis Quaid',
#   'Bess Armstrong',
#   'Simon MacCorkindale',
#   'Louis Gossett Jr.',
#   'John Putch',
#   'Lea Thompson',
#   'P.H. Moriarty',
#   'Dan Blasko',
#   'Liz Morris',
#   'Lisa Maurer'],
#  ['Lorraine Gary',
#   'Lance Guest',
#   'Mario Van Peebles',
#   'Karen Young',
#   'Michael Caine',
#   'Judith Barsi',
#   'Mitchell Anderson',
#   'Lynn Whitfield'],
#  ['Denzel Washington',
#   'Ryan Reynolds',
#   'Vera Farmiga',
#   'Brendan Gleeson',
#   'Sam Shepard',
#   'Rubén Blades',
#   'Nora Arnezeder',
#   'Robert Patrick',
#   'Liam Cunningham',
#   'Joel Kinnaman'],
#  ['Osas Ighodaro',
#   'Ini Dima-Okojie',
#   'Kemi Lala Akindoju',
#   'Toni Tones',
#   'Ebenezer Eno',
#   'Eso Okolocha DIke',
#   'Patrick Diabuah',
#   'Karibi Fubara',
#   'Temisan Emmanuel',
#   'Timini Egbuson'],
#  ['Denzel Washington',
#   'Ethan Hawke',
#   'Scott Glenn',
#   'Tom Berenger',
#   'Harris Yulin',
#   'Raymond J. Barry',
#   'Cliff Curtis',
#   'Dr. Dre',
#   'Snoop Dogg',
#   'Macy Gray',
#   'Eva Mendes'],
#  ['Richard Mofe-Damijo',
#   'Dakore Akande',
#   'Bimbo Manuel',
#   'Blossom Chukwujekwu',
#   'Deyemi Okanlawon',
#   'Etim Effiong',
#   'Denola Grey',
#   'Duke Akintola',
#   'Eku Edewor',
#   'Ade Laoye',
#   'Anee Icha',
#   'Kevin Ushi',
#   'Jude Chukwuka',
#   'Amanda Afolabi'],
#  ['Kashmira Irani',
#   'Chandan Anand',
#   'Dinesh Mehta',
#   'Ankit Arora',
#   'Pushkar Goggiaa',
#   'Anjali Rana',
#   'Aarya DharmChand Kumar',
#   'Amit Behl',
#   'Maleeka Ghai'],
#  ['Kappei Yamaguchi',
#   'Satsuki Yukino',
#   'Mieko Harada',
#   'Koji Tsujitani',
#   'Houko Kuwashima',
#   'Kumiko Watanabe',
#   'Noriko Hidaka',
#   'Kenichi Ogata',
#   'Toshiyuki Morikawa',
#   'Izumi Ogami'],
#  ['Kappei Yamaguchi',
#   'Satsuki Yukino',
#   'Koji Tsujitani',
#   'Houko Kuwashima',
#   'Kumiko Watanabe',
#   'Ken Narita',
#   'Akio Otsuka',
#   'Kikuko Inoue'],
#  ['Kappei Yamaguchi',
#   'Satsuki Yukino',
#   'Koji Tsujitani',
#   'Houko Kuwashima',
#   'Kumiko Watanabe',
#   'Noriko Hidaka',
#   'Ken Narita',
#   'Cho',
#   'Mamiko Noto',
#   'Nobutoshi Canna'],
#  ['Kappei Yamaguchi',
#   'Satsuki Yukino',
#   'Koji Tsujitani',
#   'Houko Kuwashima',
#   'Kumiko Watanabe',
#   'Kenichi Ogata',
#   'Noriko Hidaka',
#   'Hisako Kyoda',
#   'Ken Narita',
#   'Tomokazu Seki'],
#  ['Nicole Byer', 'Jacques Torres'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Rikiya Koyama',
#   'Kazuhiko Inoue',
#   'Masaki Terasoma',
#   'Mie Sonozaki',
#   'Yuichi Nakamura',
#   'Kengo Kawanishi',
#   'Kosei Hirota',
#   'Masako Katsuki'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Noriaki Sugiyama',
#   'Unsho Ishizuka',
#   'Motoko Kumai',
#   'Kazuhiko Inoue',
#   'Rikiya Koyama',
#   'Showtaro Morikubo',
#   'Nana Mizuki',
#   'Satoshi Hino',
#   'Shinji Kawada'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Kazuhiko Inoue',
#   'Satoshi Hino',
#   'Showtaro Morikubo',
#   'Kentaro Ito',
#   'Ryoka Yuzuki',
#   'Kohsuke Toriumi',
#   'Nana Mizuki',
#   'Shinji Kawada',
#   'Yoichi Masukawa',
#   'Koichi Tochika',
#   'Yukari Tamura'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Yoichi Masukawa',
#   'Koichi Tochika',
#   'Ayumi Fujimura',
#   'Keisuke Oda',
#   'Daisuke Kishio',
#   'Fumiko Orikasa',
#   'Hidetoshi Nakamura',
#   'Tetsuya Kakihara',
#   'Kisho Taniyama',
#   'Miyuki Sawashiro',
#   'Katsuyuki Konishi',
#   'Masako Katsuki',
#   'Keiko Nemoto',
#   'Masashi Ebara',
#   'Kazuhiko Inoue',
#   'Showtaro Morikubo',
#   'Romi Park',
#   'Daisuke Ono',
#   'Seizo Kato'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Satoshi Hino',
#   'Rikiya Koyama',
#   'Nobuaki Fukuda',
#   'Kenji Hamada',
#   'Keiko Nemoto',
#   'Saori Hayami',
#   'Yumi Toma',
#   'Yuko Kobayashi',
#   'Fujiko Takimoto',
#   'Mutsumi Tamura',
#   'Mayuki Makiguchi',
#   'Toshiyuki Morikawa'],
#  ['Junko Takeuchi',
#   'Gamon Kaai',
#   'Chie Nakamura',
#   'Showtaro Morikubo',
#   'Akira Ishida',
#   'Yasuyuki Kase',
#   'Urara Takano',
#   'Sachiko Kojima',
#   'Houko Kuwashima',
#   'Takako Honda'],
#  ['Junko Takeuchi',
#   'Chie Nakamura',
#   'Yoichi Masukawa',
#   'Kazuhiko Inoue',
#   'Akio Otsuka',
#   'Kyousuke Ikeda',
#   'Marika Hayashi',
#   'Umeji Sasaki',
#   'Masashi Sugawara',
#   'Hisao Egawa'],
#  ['Junko Takeuchi',
#   'Noriaki Sugiyama',
#   'Chie Nakamura',
#   'Kazuhiko Inoue',
#   'Yuhko Kaida',
#   'Tsutomu Isobe',
#   'Hirotaka Suzuoki',
#   'Jun Karasawa',
#   'Harii Kaneko',
#   'Ikuo Nishikawa'],
#  ['Winslow Fegley', 'Lidya Jewett', 'Krysten Ritter'],
#  ['Beth Chalmers', 'David Holt', 'Marcel McCalla', 'Teresa Gallagher'],
#  ['Mark-Paul Gosselaar',
#   'Tiffani Thiessen',
#   'Mario Lopez',
#   'Lark Voorhies',
#   'Elizabeth Berkley',
#   'Dustin Diamond',
#   'Dennis Haskins'],
#  ['Michael Schumacher'],
#  ['Itatí Cantoral'],
#  ['Evan Spiridellis',
#   'Erin Fitzgerald',
#   'Jeff Gill',
#   'Fred Tatasciore',
#   'Evan Michael Lee',
#   'Jared Isaacman',
#   'Sian Proctor',
#   'Chris Sembroski',
#   'Hayley Arceneaux'],
#  ['Jack Whitehall', 'Michael Whitehall'],
#  ['Sola Sobowale',
#   'Adesua Etomi',
#   'Remilekun "Reminisce" Safaru',
#   'Tobechukwu "iLLbliss" Ejiofor',
#   'Toni Tones',
#   'Paul Sambo',
#   'Jide Kosoko',
#   'Sharon Ooja'],
#  ['Bear Grylls', 'Jason Derek Prempeh'],
#  ['Daiki Yamashita',
#   'Kohsuke Toriumi',
#   'Jun Fukushima',
#   'Hiroki Yasumoto',
#   'Showtaro Morikubo',
#   'Kentaro Ito',
#   'Daisuke Kishio',
#   'Yoshitsugu Matsuoka',
#   'Junichi Suwabe',
#   'Ayaka Suwa',
#   'Megumi Han',
#   'Tomoaki Maeno',
#   'Tsubasa Yonaga',
#   'Tetsuya Kakihara',
#   'Satoshi Hino',
#   'Hiroyuki Yoshino',
#   'Atsushi Abe',
#   'Koji Yusa',
#   'Kouki Miyata',
#   'Hiro Shimono',
#   'Wataru Hatano',
#   'Yuichi Nakamura',
#   'Kenji Nojima',
#   'Mamoru Miyano',
#   'Daisuke Ono',
#   'Yuma Uchida',
#   'Jun Fukuyama'],
#  ['Sumriddhi Shukla',
#   'Jigna Bharadwaj',
#   'Sonal Kaushal',
#   'Neshma Chemburkar',
#   'Ganesh Divekar',
#   'Annamaya Verma',
#   'Anamay Verma',
#   'Manoj Pandey'],
#  ['Vijay Sethupathi', 'Parthiban', 'Raashi Khanna'],
#  ['Vijay Sethupathi', 'Parthiban', 'Raashi Khanna'],
#  ['Thomas Brodie-Sangster',
#   'Felicity Jones',
#   'Freddie Highmore',
#   'Patrick Stewart',
#   'Meera Syal',
#   'Sanjeev Bhaskar',
#   'Nonso Anozie'],
#  ['Mary Elizabeth Winstead',
#   'Jun Kunimura',
#   'Woody Harrelson',
#   'Tadanobu Asano',
#   'Miyavi',
#   'Michiel Huisman',
#   'Miku Martineau'],
#  ['Tom Ellis',
#   'Lauren German',
#   'Kevin Alejandro',
#   'D.B. Woodside',
#   'Lesley-Ann Brandt',
#   'Scarlett Estevez',
#   'Rachael Harris',
#   'Aimee Garcia',
#   'Tricia Helfer',
#   'Tom Welling',
#   'Jeremiah W. Birkett',
#   'Pej Vahdat',
#   'Michael Gladis'],
#  ['Jo Koy'],
#  ['Funke Akindele',
#   'Ayo Makun',
#   'Chioma Chukwuka Akpotha',
#   'Yemi Eberechi Alade',
#   'Blossom Chukwujekwu',
#   'Deyemi Okanlawon',
#   'Alexx Ekubo',
#   'Zubby Michael',
#   'Tina Mba',
#   'Femi Jacobs'],
#  ['Ikue Otani',
#   'Sarah Natochenny',
#   'Zeno Robinson',
#   'Cherami Leigh',
#   'James Carter Cathcart',
#   'Michele Knotz',
#   'Rodger Parsons',
#   'Ray Chase',
#   'Casey Mongillo',
#   'Tara Sands'],
#  ['David Kross',
#   'Hanno Koffler',
#   'Maria Ehrich',
#   'Robert Finster',
#   'Yung Ngo',
#   'Klaus Steinbacher',
#   'Livia Matthes',
#   'Nellie Thalbach'],
#  ['Jeon Hae-ri', 'Kim Eun-ah', 'Hong Bum-ki', 'Nam Do-hyeong', 'Um Sang-hyun'],
#  ['Malcolm X', 'Muhammad Ali'],
#  ['Julie Tejwani',
#   'Sabina Malik',
#   'Jigna Bhardwaj',
#   'Rupa Bhimani',
#   'Lalit Agarwal',
#   'Rajesh Shukla',
#   'Rajesh Kava'],
#  ['Emma Roberts',
#   'Danielle Macdonald',
#   'Awkwafina',
#   'Eiza González',
#   'Milla Jovovich',
#   'Jeremy Irvine',
#   'Arnaud Valois',
#   'Daniel Horvath'],
#  ['Pauline Etienne',
#   'Laurent Capelluto',
#   'Stefano Cassetti',
#   'Mehmet Kurtuluş',
#   'Babetida Sadjo',
#   'Jan Bijvoet',
#   'Ksawery Szlenkier',
#   'Vincent Londez',
#   'Regina Bikkinina',
#   'Alba Gaïa Kraghede Bellugi',
#   'Nabil Mallat'],
#  ['Elsa Öhrn',
#   'Mustapha Aarab',
#   'Jonay Pineda Skallak',
#   'Magnus Krepper',
#   'Loreen',
#   'Albin Grenholm',
#   'Simon Mezher',
#   'Elsa Bergström Terent',
#   'Josef Kadim',
#   'Yohannes Frezgi'],
#  ['Will Arnett',
#   'Ludacris',
#   'Natasha Lyonne',
#   'Stanley Tucci',
#   'Jordin Sparks',
#   'Gabriel Iglesias',
#   "Shaquille O'Neal",
#   'Omar Chaparro',
#   'Alan Cumming',
#   'Andy Beckwith',
#   'Delia Sheppard',
#   'Kerry Shale'],
#  ['Michelle Buteau'],
#  ['Ronnie Van Zandt',
#   'Gary Rossington',
#   'Allen Collins',
#   'Leon Wilkeson',
#   'Bob Burns',
#   'Billy Powell',
#   'Ed King',
#   'Artimus Pyle',
#   'Steve Gaines',
#   'Johnny Van Zant'],
#  ['Jack Fisher',
#   'Tom Kenny',
#   'Amanda C. Miller',
#   'Kim Yarbrough',
#   'Keith Ferguson',
#   'Grey Griffin',
#   'Lily Rose Silver'],
#  ['Antonio Aakeel',
#   'Chipo Chung',
#   'Simon Foster',
#   'Teresa Gallagher',
#   'Simon Greenall',
#   'Kate Harbour',
#   'Paul Panting',
#   'Rob Rackstraw',
#   'William Vanderpuye',
#   'Helen Walsh',
#   'Keith Wickham',
#   'Andres Williams',
#   'Jo Wyatt'],
#  ['Julie Delpy',
#   'Elisabeth Shue',
#   'Sarah Jones',
#   'Alexia Landeau',
#   'Mathieu Demy',
#   'Troy Garity',
#   'Timm Sharp',
#   'Giovanni Ribisi'],
#  ['Austin Abell',
#   'Travis Turner',
#   'Cole Howard',
#   'Anna Cummer',
#   'Jesse Inocalla',
#   'Brian Dobson',
#   'Michael Adamthwaite',
#   'Joseph Girgis',
#   'Caitlyn Bairstow'],
#  ['Jide Kosoko',
#   'Omotola Jalade-Ekeinde',
#   'Yemi Blaq',
#   'Sola Sobowale',
#   'Ken Erics',
#   'Toyin Aimakhu',
#   'Segun Arinze',
#   'Jibola Dabo',
#   'Rotimi Salami',
#   'Pa Jimi Solanke',
#   'Rachael Okonkwo',
#   'Bassey Okon',
#   'Lucien Morgan',
#   'Magdalena Korpas'],
#  ['Robyn Slade', 'Kami Desilets'],
#  ['Antony Varghese',
#   'Reshma Rajan',
#   'Binny Rinky Benjamin',
#   'Vineeth Vishwam',
#   'Kichu Tellus',
#   'Sreekanth Dasan',
#   'Sarath Kumar',
#   'Tito Wilson',
#   'Anandhu',
#   'Bitto Davis',
#   'Sinoj Varghese'],
#  ['Peyton List',
#   'Karan Brar',
#   'Skai Jackson',
#   'Miranda May',
#   'Kevin G. Quinn',
#   'Nathan Arenas',
#   'Nina Lu'],
#  ['Mandy Grace',
#   'David de Vos',
#   'Donna Rusch',
#   'Devan Key',
#   'Isabella Mancuso',
#   'Ariana Guido'],
#  ['Aubri Ibrag',
#   "Sana'a Shaik",
#   'Miah Madden',
#   'Mercy Cornwall',
#   'Georgia-May Davis',
#   'Ryan Harrison',
#   'Josh Heuston',
#   'Alexander Grant'],
#  ['Úrsula Corberó',
#   'Itziar Ituño',
#   'Álvaro Morte',
#   'Paco Tous',
#   'Enrique Arce',
#   'Pedro Alonso',
#   'María Pedraza',
#   'Alba Flores',
#   'Miguel Herrán',
#   'Jaime Lorente',
#   'Esther Acebo',
#   'Darko Peric',
#   'Kiti Mánver'],
#  ['Liam Mitchell',
#   'Dee Bradley Baker',
#   'Grey Griffin',
#   'Josh McDermitt',
#   'Kari Wahlgren',
#   'Judy Alice Lee',
#   'Ali Mawji'],
#  ['Michael Keaton',
#   'Stanley Tucci',
#   'Amy Ryan',
#   'Shunori Ramanathan',
#   'Ato Blankson-Wood',
#   'Tate Donovan',
#   'Laura Benanti',
#   'Chris Tardio'],
#  ['Victoria Justice',
#   'Midori Francis',
#   'Robyn Scott',
#   'Adam Garcia',
#   'Timothy Renouf',
#   'Gloria Garcia',
#   'Myfanwy Waring',
#   'Spencer Sutherland'],
#  ['Madhuri Dixit',
#   'Shah Rukh Khan',
#   'Tinnu Anand',
#   'Johny Lever',
#   'Kalpana Iyer',
#   'Himani Shivpuri',
#   'Sudha Chandran',
#   'Beena',
#   'Kiran Kumar'],
#  ['Abbie Cornish',
#   'Ben Whishaw',
#   'Paul Schneider',
#   'Kerry Fox',
#   'Edie Martin',
#   'Thomas Brodie-Sangster',
#   'Claudie Blakley',
#   'Gerard Monaco',
#   'Antonia Campbell-Hughes',
#   'Samuel Roukin'],
#  ['Krrish Chhabria',
#   'Hetal Gada',
#   'Vipin Sharma',
#   'Gulfam Khan',
#   'Suresh Menon',
#   'Vijay Maurya',
#   'Rajiv Lakshman',
#   'Ninad Kamat'],
#  ['Akshay Oberoi',
#   'Pankaj Tripathi',
#   'Ragini Khanna',
#   'Aamir Bashir',
#   'Shalini Vatsa',
#   'Ashish Verma'],
#  ['Janine Gutierrez',
#   'JC Santos',
#   'Victor Anastacio',
#   'Yesh Burce',
#   'Lotlot De Leon'],
#  ['Jon Allen', 'Kellen Goff', 'Joe Hernandez', 'Kaiji Tang'],
#  ['Lee Ji-eun',
#   'Yeo Jin-goo',
#   'Shin Jung-geun',
#   'Seo Yi-sook',
#   'Bae Hae-sun',
#   'Pyo Ji-hoon',
#   'Cho Hyun-chul',
#   'Kang Hong-suk',
#   'Lee Do-hyun',
#   'Lee Tae-seon',
#   'Kang Mina',
#   'Park You-na',
#   'Oh Ji-ho'],
#  ['Meg Ryan',
#   'Mark Ruffalo',
#   'Jennifer Jason Leigh',
#   'Nick Damici',
#   'Sharrieff Pugh',
#   'Kevin Bacon',
#   'Yaani King Mondschein',
#   'Heather Litteer'],
#  ['Sean Hayes',
#   'Wanda Sykes',
#   'Laurie Metcalf',
#   'David Harbour',
#   'Gary Cole',
#   'Patti Harrison',
#   'Matt Rogers'],
#  ['Aadil Khan',
#   'Sadia Khateeb',
#   'Zain Khan Durrani',
#   'Priyanshu Chatterjee',
#   'Bhavna Chauhan',
#   'Ashwin Dhar',
#   'Farid Azad Khan',
#   'Saghar Sehrai'],
#  ['Hilary Duff',
#   'Chad Michael Murray',
#   'Jennifer Coolidge',
#   'Dan Byrd',
#   'Regina King',
#   'Julie Gonzalo',
#   'Lin Shaye',
#   'Madeline Zima',
#   'Andrea Avery',
#   'Mary Pat Gleason',
#   'Paul Rodriguez',
#   'Whip Hubley',
#   'Kevin Kilner',
#   'Erica Hubbard',
#   'Simon Helberg'],
#  ['Glenn Close',
#   'Terence Stamp',
#   'Max Irons',
#   'Gillian Anderson',
#   'Christina Hendricks',
#   'Stefanie Martini',
#   'Julian Sands',
#   'Honor Kneafsey',
#   'Christian McKay',
#   'Amanda Abbington'],
#  ['Robert Redford',
#   'Jennifer Lopez',
#   'Morgan Freeman',
#   'Josh Lucas',
#   'Damian Lewis',
#   'Camryn Manheim',
#   'Becca Gardner',
#   'Lynda Boyd',
#   'Rob Hayter',
#   'P. Lynn Johnson'],
#  ['America Young',
#   'Amber May',
#   'Giselle Fernandez',
#   'Alejandro Saab',
#   'Dinora Walcott'],
#  ['Harrison Ford',
#   'Rutger Hauer',
#   'Sean Young',
#   'Edward James Olmos',
#   'M. Emmet Walsh',
#   'Daryl Hannah',
#   'William Sanderson',
#   'Brion James',
#   'Joe Turkel',
#   'Joanna Cassidy',
#   'James Hong',
#   'Morgan Paull'],
#  ['Tseng Yun-fan',
#   'Kao Yun-shuo',
#   'Chiang Ching-yen',
#   'Meng Ching-fu',
#   'Huang Bai-wei',
#   'Ma Kuo-yao',
#   'Chen Yen-chun',
#   'Sun Ke-fang',
#   'Kai Yang-niu',
#   'Chen Yu-wen',
#   'Nick Liao',
#   'Lin Kai-ling',
#   'Mickey Huang',
#   'Liu Kuan-ting',
#   'Jiang Du-hui'],
#  ['Sharlto Copley',
#   'Hugh Jackman',
#   'Sigourney Weaver',
#   'Dev Patel',
#   'Ninja',
#   'Yo-Landi Visser',
#   'Jose Pablo Cantillo',
#   'Brandon Auret',
#   'Johnny Selema',
#   'Maurice Carpede'],
#  ['Harrison Ford',
#   'Willem Dafoe',
#   'Anne Archer',
#   'Joaquim de Almeida',
#   'Henry Czerny',
#   'Harris Yulin',
#   'Donald Moffat',
#   'Miguel Sandoval',
#   'Benjamin Bratt',
#   'Dean Jones',
#   'Thora Birch',
#   'James Earl Jones',
#   'Raymond Cruz'],
#  ['Sylvester Stallone',
#   'John Lithgow',
#   'Michael Rooker',
#   'Janine Turner',
#   'Rex Linn',
#   'Caroline Goodall',
#   'Leon',
#   'Craig Fairbrass',
#   'Ralph Waite',
#   'Max Perlich',
#   'Paul Winfield'],
#  ['Jude Law',
#   'Nicole Kidman',
#   'Renée Zellweger',
#   'Eileen Atkins',
#   'Brendan Gleeson',
#   'Philip Seymour Hoffman',
#   'Natalie Portman',
#   'Giovanni Ribisi',
#   'Donald Sutherland',
#   'Ray Winstone'],
#  ['Paul Hogan',
#   'Linda Kozlowski',
#   'Jere Burns',
#   'Jonathan Banks',
#   'Aida Turturro',
#   'Alec Wilson',
#   'Gerry Skilton',
#   'Steve Rackman',
#   'Serge Cockburn',
#   'Paul Rodriguez',
#   'Mark Adair-Rios',
#   'Tiriel Mora',
#   'Grant Piro',
#   'Mike Tyson'],
#  ['Channing Tatum',
#   'Amanda Seyfried',
#   'Richard Jenkins',
#   'Henry Thomas',
#   'D.J. Cotrona',
#   'Cullen Moss',
#   'Gavin McCulley',
#   'Jose Lucena Jr.',
#   'Keith Robinson',
#   'Scott Porter'],
#  ['Danny Aiello',
#   'Ossie Davis',
#   'Ruby Dee',
#   'Richard Edson',
#   'Giancarlo Esposito',
#   'Spike Lee',
#   'Bill Nunn',
#   'John Turturro',
#   'Paul Benjamin',
#   'Frankie Faison',
#   'Samuel L. Jackson',
#   'Rosie Perez',
#   'Martin Lawrence',
#   'Miguel Sandoval'],
#  ['Joaquín Furriel',
#   'Luis Ziembrowski',
#   'Guillermo Pfening',
#   'Mónica Lairana',
#   'Germán de Silva',
#   'Victoria Raposo',
#   'Andrea Garrote'],
#  ['Bruce Willis',
#   'Kellan Lutz',
#   'Gina Carano',
#   'D.B. Sweeney',
#   'Joshua Mikel',
#   'Steve Coulter',
#   'Dan Bilzerian',
#   'Heather Johansen'],
#  ['Hilary Swank',
#   'Patrick Dempsey',
#   'Scott Glenn',
#   'Imelda Staunton',
#   'April L. Hernandez',
#   'Mario',
#   'Kristin Herrera',
#   'Jaclyn Ngan',
#   'Sergio Montalvo',
#   'Jason Finn',
#   'Deance Wyatt',
#   'Vanetta Smith'],
#  ['Ryan Reynolds',
#   'Blake Lively',
#   'Peter Sarsgaard',
#   'Mark Strong',
#   'Tim Robbins',
#   'Jay O. Sanders',
#   'Taika Waititi',
#   'Angela Bassett'],
#  ['Christopher Reid',
#   'Christopher Martin',
#   'Robin Harris',
#   'Tisha Campbell',
#   'A.J. Johnson',
#   'Martin Lawrence',
#   'Paul Anthony',
#   'Bowlegged Lou',
#   'B-Fine',
#   'Edith Fields',
#   'Kelly Jo Minter',
#   'Clifton Powell',
#   'Verda Bridges'],
#  ['Christopher Reid',
#   'Christopher Martin',
#   'Martin Lawrence',
#   'Bowlegged Lou',
#   'Paul Anthony',
#   'B-Fine',
#   'Tisha Campbell',
#   'Kamron',
#   'Iman',
#   'Queen Latifah'],
#  ['Christopher Reid',
#   'Christopher Martin',
#   'Tisha Campbell',
#   'David Edwards',
#   'Angela Means',
#   'Ketty Lester',
#   'Bernie Mac',
#   'Michael Colyar',
#   'Chris Tucker',
#   'Khandi Alexander'],
#  ['Hakeem Kae-Kazim',
#   'Chioma Omeruah',
#   'Orukotan Adejola',
#   'Flora Chiedo',
#   'Emeka Nwagbaraocha',
#   'Anthony Oseyemi',
#   'Oluwabukola Thomas',
#   'Soibifaa Dokubo'],
#  ['Master P',
#   'Anthony Johnson',
#   'Gretchen Palmer',
#   'Frantz Turner',
#   'Richard Keats',
#   'Joe Estevez',
#   'William Knight',
#   'Anthony Boswell',
#   "Tommy 'Tiny' Lister",
#   'Helen Martin',
#   'John Witherspoon',
#   'Mia X'],
#  ['Omar Epps',
#   'LL Cool J',
#   'Nia Long',
#   'Stanley Tucci',
#   'Pam Grier',
#   'Hill Harper',
#   'Jake Weber',
#   'David Patrick Kelly',
#   'Veronica Webb',
#   'Ron Canada',
#   'Robert LaSardo',
#   'Gano Grills',
#   'Ivonne Coll',
#   'Don Harvey',
#   'Mya',
#   "Nasir 'Nas' Jones",
#   'Jermaine Dupri'],
#  ['Jay Chou',
#   'Anne Suzuki',
#   'Edison Chen',
#   'Anthony Wong Chau-sang',
#   'Shawn Yue',
#   'Chapman To',
#   'Jordan Chan',
#   'Kenny Bee'],
#  ['Jai Brooks',
#   'Luke Brooks',
#   'James Yammouni',
#   'Daniel Sahyounie',
#   'Beau Brooks'],
#  ['Lori Gardner',
#   'Kate Bristol',
#   'Billy Bob Thompson',
#   'Marc Thompson',
#   'Erica Schroeder'],
#  ['Kensho Ono',
#   'Yuki Ono',
#   'Chiwa Saito',
#   'Yoshimasa Hosoya',
#   'Hirofumi Nojima',
#   'Kenji Hamada',
#   'Takuya Eguchi',
#   'Soichiro Hoshi',
#   'Tatsuhisa Suzuki',
#   'Go Inoue',
#   'Daisuke Ono',
#   'Ryohei Kimura',
#   'Junichi Suwabe',
#   'Kazuya Nakai',
#   'Fumiko Orikasa',
#   'Kenichi Suzumura',
#   'Kisho Taniyama',
#   'Hiroshi Kamiya'],
#  ['David Bowie',
#   'Jennifer Connelly',
#   'Frank Oz',
#   'Kevin Clash',
#   'Anthony Asbury',
#   'Dave Goelz',
#   'Brian Henson',
#   'Ron Mueck',
#   'Karen Prell',
#   'Shari Weiser'],
#  ['Amanda Seyfried',
#   'Christopher Egan',
#   'Gael García Bernal',
#   'Vanessa Redgrave',
#   'Franco Nero',
#   'Luisa Ranieri',
#   'Marina Massironi',
#   'Milena Vukotic',
#   'Marcia DeBonis',
#   'Luisa De Santis',
#   'Lidia Biondi',
#   'Giordano Formenti',
#   'Chris Egan'],
#  ['Katie Douglas',
#   'Celina Martin',
#   'Peter Outerbridge',
#   'Sara Canning',
#   'Alexis Whelan',
#   'Amalia Williamson',
#   'Josette Halpert',
#   'Kiana Madeira'],
#  ['Nick Cannon',
#   'Christina Milian',
#   'Kenan Thompson',
#   'Kal Penn',
#   'Steve Harvey',
#   'Al Thompson',
#   'Ashley Monique Clark',
#   'Elimu Nelson',
#   'Nichole Robinson',
#   'Melissa Schuman'],
#  ['Miriam Chin Wah Yeung',
#   'Shawn Yue',
#   'Singh Hartihan Bitto',
#   'Isabel Chan',
#   'Cheung Tat-ming',
#   'Matt Chow',
#   'Chui Tien-you',
#   'Queenie Chu',
#   'Charmaine Fong',
#   'Vincent Kok'],
#  ['Gerald McRaney',
#   'Shanna Reed',
#   'Nicole Dubuc',
#   'Chelsea Hertford',
#   'Marisa Ryan',
#   'Matt Mulhern',
#   'Beverly Archer',
#   'Jon Cypher'],
#  ['Jack Nicholson',
#   'Glenn Close',
#   'Annette Bening',
#   'Pierce Brosnan',
#   'Danny DeVito',
#   'Martin Short',
#   'Sarah Jessica Parker',
#   'Michael J. Fox',
#   'Rod Steiger',
#   'Tom Jones',
#   'Lukas Haas',
#   'Natalie Portman'],
#  ['Chadwick Boseman',
#   'Josh Gad',
#   'Kate Hudson',
#   'Sterling K. Brown',
#   'Dan Stevens',
#   'James Cromwell',
#   'Keesha Sharp',
#   'Roger Guenveur Smith',
#   'Derrick Baskin',
#   'Barrett Doss'],
#  ['Ashton Kutcher',
#   'Tara Reid',
#   'Jeffrey Tambor',
#   'Andy Richter',
#   'Michael Madsen',
#   'Jon Abrahams',
#   'David Koechner',
#   'Carmen Electra',
#   'Kenan Thompson',
#   'Terence Stamp',
#   'Molly Shannon'],
#  ['Ben Stiller',
#   'Hank Azaria',
#   'William H. Macy',
#   'Janeane Garofalo',
#   'Kel Mitchell',
#   'Paul Reubens',
#   'Wes Studi',
#   'Greg Kinnear',
#   'Geoffrey Rush',
#   'Lena Olin',
#   'Eddie Izzard',
#   'Artie Lange',
#   'Pras',
#   'Claire Forlani',
#   'Tom Waits'],
#  ['Patricio Contreras',
#   'Alejandro Goic',
#   'Sergio Hernández',
#   'Mariana Loyola Ruz',
#   'Alejandro Trejo',
#   'Daniel Alcaíno Cuevas',
#   'Nicolás Poblete',
#   'Susana Hidalgo',
#   'Gloria Münchmeyer'],
#  ['Robert De Niro',
#   'James Woods',
#   'Elizabeth McGovern',
#   'Treat Williams',
#   'Tuesday Weld',
#   'Burt Young',
#   'Joe Pesci',
#   'Danny Aiello',
#   'William Forsythe',
#   'James Hayden'],
#  ['Joel McHale',
#   'Mike Epps',
#   'Jane Krakowski',
#   'Billy Connolly',
#   'Crispin Glover',
#   'Steve Schirripa',
#   'Georgia Engel',
#   'Diedrich Bader',
#   'Cody Cameron',
#   'Fred Stoller',
#   'Olivia Hack'],
#  ['Chris Rock',
#   'Laurence Fishburne',
#   'David Hyde Pierce',
#   'Brandy Norwood',
#   'William Shatner',
#   'Ron Howard',
#   'Kid Rock',
#   'Ben Stein'],
#  ['Josh Lucas',
#   'Kurt Russell',
#   'Jacinda Barrett',
#   'Richard Dreyfuss',
#   'Emmy Rossum',
#   'Mía Maestro',
#   'Mike Vogel',
#   'Kevin Dillon',
#   'Freddy Rodríguez'],
#  ['Too $hort',
#   'B-Real',
#   'Kurtis Blow',
#   'Da Brat',
#   'Grandmaster Caz',
#   'Sean "P. Diddy" Combs',
#   'Chuck D.',
#   'Desiree Densiti',
#   'Dr. Dre',
#   'E-40',
#   'MC Eiht',
#   'Heavy D',
#   'Lauryn Hill',
#   'Ice-T',
#   'Wyclef Jean',
#   'Ras Kass',
#   'KRS-One',
#   'L.V.',
#   'Mack 10',
#   'Craig Mack',
#   'Method Man',
#   'Keith Murray',
#   "Nasir 'Nas' Jones",
#   'The Notorious B.I.G.',
#   'Master P',
#   'Q-Tip',
#   'Raekwon',
#   'Redman',
#   'Senen Reyes',
#   'Busta Rhymes',
#   'RZA',
#   'DJ Scratch',
#   'Erick Sermon',
#   'Tupac Shakur',
#   'Adario Strange',
#   'Suave'],
#  ['Greg Kinnear',
#   'Renée Zellweger',
#   'Djimon Hounsou',
#   'Jon Voight',
#   'Olivia Holt'],
#  ['Jack Black',
#   'Joan Cusack',
#   'Mike White',
#   'Sarah Silverman',
#   'Lee Wilkof',
#   'Kate McGregor-Stewart',
#   'Adam Pascal',
#   'Suzzanne Douglas',
#   'Miranda Cosgrove',
#   'Kevin Alexander Clark',
#   'Joey Gaydos Jr.',
#   'Robert Tsai',
#   'Veronica Afflerbach',
#   'Jordan-Claire Green'],
#  ['Tyler Oakley'],
#  ['Bruce Willis',
#   'Monica Bellucci',
#   'Cole Hauser',
#   'Eamonn Walker',
#   'Johnny Messner',
#   'Nick Chinlund',
#   'Charles Ingram',
#   'Paul Francis',
#   'Chad Smith',
#   'Tom Skerritt',
#   'Malick Bowens',
#   'Awaovieyi Agie'],
#  ['Brooke Shields',
#   'Christopher Atkins',
#   'Leo McKern',
#   'William Daniels',
#   'Elva Josephson',
#   'Glenn Kohan',
#   'Alan Hopgood',
#   'Gus Mercurio'],
#  ['Eddie Murphy',
#   'J.L. Reate',
#   'Charles Dance',
#   'Charlotte Lewis',
#   'Victor Wong',
#   'Randall Tex Cobb',
#   'James Hong',
#   'Shakti Chen',
#   'Tau Logo',
#   'Tiger Chung Lee'],
#  ['Gregory Peck',
#   'David Niven',
#   'Anthony Quinn',
#   'Stanley Baker',
#   'Anthony Quayle',
#   'James Darren',
#   'Irene Papas',
#   'Gia Scala',
#   'James Robertson Justice',
#   'Richard Harris'],
#  ['James Franco',
#   'Seth Rogen',
#   'Lizzy Caplan',
#   'Randall Park',
#   'Diana Bang',
#   'Timothy Simons',
#   'Reese Alexander',
#   'James Yi'],
#  ['Eddie Murphy',
#   'Jada Pinkett Smith',
#   'James Coburn',
#   'Larry Miller',
#   'Dave Chappelle',
#   'John Ales',
#   'Patricia Wilson',
#   'Jamal Mixon'],
#  ['Eddie Murphy',
#   'Janet Jackson',
#   'Larry Miller',
#   'John Ales',
#   'Richard Gant',
#   'Anna Maria Horsford',
#   'Melinda McGraw',
#   'Jamal Mixon',
#   'Gabriel Williams',
#   'Chris Elliott'],
#  ['Martin Lawrence',
#   'James Earl Jones',
#   'Joy Bryant',
#   'Margaret Avery',
#   'Mike Epps',
#   "Mo'Nique",
#   'Cedric the Entertainer',
#   'Nicole Ari Parker',
#   'Michael Clarke Duncan',
#   'Louis C.K.'],
#  ['Clint Eastwood',
#   'John Malkovich',
#   'Rene Russo',
#   'Dylan McDermott',
#   'Gary Cole',
#   'Fred Thompson',
#   'John Mahoney',
#   'Gregory Alan Williams',
#   'Jim Curley',
#   'Sally Hughes'],
#  ['Marie Kondo'],
#  ['Shin Min-a',
#   'Kim Seon-ho',
#   'Lee Sang-yi',
#   'Gong Min-jeung',
#   'Kim Young-ok',
#   'Cho Han-cheul',
#   'In Gyo-jin',
#   'Lee Bong-ryeon',
#   'Cha Cheong-hwa',
#   'Kang Hyung-suk'],
#  ['Kenjiro Tsuda'],
#  ['Ramzy Bedia',
#   'Éric Judor',
#   'Benoît Magimel',
#   'Kristin Scott Thomas',
#   'Élodie Bouchez',
#   'Édouard Baer',
#   'Fred Testot',
#   'Omar Sy'],
#  ['Um Sang-hyun',
#   'Park Yoon-hee',
#   'Kang Shi-hyun',
#   'Hong Bum-ki',
#   'Kim Hyun-wook',
#   'Lee In-suk',
#   'Song Ha-rim'],
#  ['Satya Dev', 'Priyanka Jawalkar', 'Brahmaji'],
#  ['Jeremy Renner',
#   'Elizabeth Olsen',
#   'Jon Bernthal',
#   'Gil Birmingham',
#   'Kelsey Asbille',
#   'Tantoo Cardinal',
#   'Teo Briones',
#   'Matthew Del Negro',
#   'Hugh Dillon',
#   'Julia Jones',
#   'James Jordan',
#   'Eric Lange',
#   'Martin Sensmeier',
#   'Mason Davis',
#   'Graham Greene'],
#  ['Mithun Chakraborty',
#   'Tusshar Kapoor',
#   'Anupam Kher',
#   'Rajpal Yadav',
#   'Raima Sen',
#   'Dilip Prabhavalkar',
#   'Sanjay Mishra'],
#  ['Jung Hae-in', 'Koo Kyo-hwan', 'Kim Sung-kyun', 'Son Suk-ku'],
#  ['Frank Ramirez',
#   'Patricia Castañeda',
#   'Chela del Río',
#   'Patrick Delmas',
#   'María José Martínez',
#   'Robinson Díaz',
#   'Juan Ángel',
#   'Guillermo Olarte',
#   'Constanza Duque',
#   'Marcela Carvajal'],
#  ['Sanjay Dutt',
#   'Arjun Rampal',
#   'Malaika Arora',
#   'Aashish Chaudhary',
#   'Neha Uberoi',
#   'Urmila Matondkar',
#   'Manoj Joshi',
#   'Daya Shankar Pandey',
#   'Pushkar Jog',
#   'Kulbhushan Kharbanda'],
#  ['Addison Rae',
#   'Tanner Buchanan',
#   'Rachael Leigh Cook',
#   'Madison Pettis',
#   'Isabella Crovetti',
#   'Matthew Lillard',
#   'Peyton Meyer',
#   'Annie Jacob',
#   'Myra Molloy',
#   'Kourtney Kardashian'],
#  ['Michael J. Woodard',
#   'Mary Lambert',
#   'Jonathan Van Ness',
#   'Haley Tju',
#   'Brett Gelman',
#   'Tony Hale',
#   'Vincent Rodriguez III',
#   'Annie Potts',
#   'Jessica Williams',
#   'Melissa Villaseñor',
#   'Cathy Vu',
#   'Jennifer Coolidge',
#   'Flea'],
#  ['Sola Sobowale',
#   'Toni Tones',
#   'Richard Mofe-Damijo',
#   'Efa Iwara',
#   'Titi Kuti',
#   'Tobechukwu "iLLbliss" Ejiofor',
#   'Remilekun "Reminisce" Safaru',
#   'Charles  "Charly Boy" Oputa',
#   'Nse Ikpe-Etim',
#   'Keppy Ekpenyong Bassey',
#   'Bimbo Manuel',
#   'Akin Lewis',
#   'Lord Frank',
#   'Osas Ighodaro',
#   'Taiwo Ajai-Lycett',
#   'Paul Sambo'],
#  ['Aftab Shivdasani',
#   'Natassha',
#   'Dipannita Sharma',
#   'Himanshu Mallik',
#   'Vaidya Advai',
#   'Pushy Anand',
#   'Shama Deshpande',
#   'Rajendra Gupta'],
#  ['Sohail Khan',
#   'Isha Koppikar',
#   'Natassha',
#   'Rati Agnihotri',
#   'Vrajesh Hirjee',
#   'Divya Palat',
#   'Hiten Tejwani',
#   'Rajendranath Zutshi'],
#  ['Tusshar Kapoor',
#   'Esha Deol',
#   'Natassha',
#   'Vrajesh Hirjee',
#   'Kusumit Sana',
#   'Rishi Kapoor',
#   'Moon Moon Sen',
#   'Johny Lever',
#   'Ashay Chitre',
#   'Jeetendra'],
#  ['Tusshar Kapoor',
#   'Riteish Deshmukh',
#   'Isha Koppikar',
#   'Neha Dhupia',
#   'Anupam Kher',
#   'Jay Sean'],
#  ['Tusshar Kapoor',
#   'Aftab Shivdasani',
#   'Krishna Abhishek',
#   'Mandana Karimi',
#   'Shakti Kapoor',
#   'Darshan Jariwala',
#   'Sushmita Mukherjee',
#   'Meghna Naidu',
#   'Anand Kumar',
#   'Claudia Ciesla'],
#  ['Tusshar Kapoor',
#   'Riteish Deshmukh',
#   'Anupam Kher',
#   'Rohit Shetty',
#   'Neha Sharma',
#   'Chunky Pandey',
#   'Sarah-Jane Dias',
#   'Razak Khan',
#   'Kavin Dave'],
#  ['Govinda',
#   'Sushmita Sen',
#   'Rambha',
#   'Anupam Kher',
#   'Satish Kaushik',
#   'Sharad Kapoor',
#   'Kiran Kumar',
#   'Mohnish Bahl'],
#  ['Nushrat Bharucha',
#   'Anshuman Jha',
#   'Neha Chauhan',
#   'Rajkummar Rao',
#   'Arya Banerjee',
#   'Amit Sial',
#   'Herry Tangri'],
#  ['Vivek Oberoi',
#   'Zayed Khan',
#   'Shriya Saran',
#   'Nikitin Dheer',
#   'Shabbir Ahluwalia',
#   'Sunil Shetty',
#   'Shweta Bhardwaj'],
#  ['Ajay Devgn',
#   'Emraan Hashmi',
#   'Kangana Ranaut',
#   'Prachi Desai',
#   'Randeep Hooda',
#   'Naved Aslam',
#   'Asif Basra',
#   'Avtar Gill'],
#  ['Akshay Kumar',
#   'Imran Khan',
#   'Sonakshi Sinha',
#   'Sonali Bendre',
#   'Sarfaraz Khan',
#   'Mahesh Manjrekar',
#   'Abhimanyu Singh',
#   'Kurush Deboo',
#   'Pitobash',
#   'Chetan Hansraj'],
#  ['Kainaz Motivala',
#   'Rajkummar Rao',
#   'Rajat Kaul',
#   'Janice',
#   'Shernaza',
#   'Mangala Ahire',
#   'Vinod Rawat'],
#  ['Sunny Leone',
#   'Saahil Prem',
#   'Parvin Dabas',
#   'Sandhya Mridul',
#   'Divya Dutta',
#   'Soniya Mehra',
#   'Kainaz Motivala',
#   'Karan Mehra'],
#  ['Charlie Murphy',
#   'Ruth Bradley',
#   'Sarah Greene',
#   'Brian Gleeson',
#   'Michelle Fairley',
#   'Ian McElhinney',
#   'Michael Ford-FitzGerald',
#   'Paul Reid',
#   'Barry Ward',
#   'Tom Turner',
#   'Perdita Weeks',
#   'Andrew Simpson',
#   'Sophie Robinson'],
#  ['King & Prince',
#   'Hey! Say! JUMP',
#   'KAT-TUN',
#   'NEWS',
#   "Kansai Johnny's Jr.",
#   'Snow Man',
#   'Tomoyuki Yara',
#   'Travis Japan',
#   'Bi shonen',
#   'SixTONES',
#   'HiHi Jets',
#   'Kis-My-Ft2',
#   'Koichi Domoto'],
#  ['Sam Heughan',
#   'Ruby Rose',
#   'Andy Serkis',
#   'Hannah John-Kamen',
#   'Tom Wilkinson',
#   'Tom Hopper',
#   'Noel Clarke',
#   'Anne Reid',
#   'Owain Yeoman',
#   'Jing Lusi',
#   'Ray Panthaki',
#   'Richard McCabe',
#   'Douglas Reith'],
#  ['Amitabh Bachchan',
#   'Sanjay Dutt',
#   'Sunil Shetty',
#   'Arbaaz Khan',
#   'Abhishek Bachchan',
#   'Vivek Oberoi',
#   'Tusshar Kapoor',
#   'Rohit Roy',
#   'Shabbir Ahluwalia',
#   'Dia Mirza',
#   'Amrita Singh',
#   'Neha Dhupia'],
#  ['Sendhil Ramamurthy',
#   'Tusshar Kapoor',
#   'Nikhil Dwivedi',
#   'Preeti Desai',
#   'Sundeep Kishan',
#   'Radhika Apte',
#   'Pitobash',
#   'Girija Oak',
#   'Alok Chaturvedi',
#   'Sudhir Chowdhary'],
#  ['Vidya Balan',
#   'Emraan Hashmi',
#   'Tusshar Kapoor',
#   'Naseeruddin Shah',
#   'Rajesh Sharma',
#   'Imran Hasnee',
#   'Anju Mahendru'],
#  ['Takuma Terashima',
#   'Mikako Komatsu',
#   'Rie Kugimiya',
#   'Hiromichi Tezuka',
#   'Shiori Izawa',
#   'Shiki Aoki',
#   'Sayaka Ohara',
#   'Hochu Otsuka',
#   'Kikuko Inoue'],
#  ['Loretta Devine',
#   'Tia Mowry-Hardrict',
#   'Anthony Alabi',
#   'Talia Jackson',
#   'Isaiah Russell-Bailey',
#   'Cameron J. Wright',
#   'Jordyn Raya James',
#   'Richard Roundtree'],
#  ['Bob Ross'],
#  ['Zoe Kazan',
#   'Betty Gabriel',
#   'Adrian Grenier',
#   'Phoenix Raei',
#   'Abraham Lim',
#   'Jessica Collins',
#   'Camaron Engels',
#   'Jaylin Fletcher',
#   'Liz Alexander',
#   'Joyce Guy',
#   'Daniel Henshall',
#   'Ian Meadows',
#   'Jamie Timony',
#   'Steve Mouzakis',
#   'Becca Lish'],
#  ['Maria Wawreniuk',
#   'Ignacy Liss',
#   'Michał Sikorski',
#   'Wojciech Dolatowski',
#   'Klaudia Koścista',
#   'Zuzanna Galewicz',
#   'Marta Nieradkiewicz',
#   'Sara Celler Jezierska',
#   'Pola Król',
#   'Marcin Czarnik',
#   'Martyna Nowakowska'],
#  ['Kathrine Thorborg Johansen',
#   'Elias Holmen Sørensen',
#   'André Sørum',
#   'Kim Fairchild',
#   'Sara Khorami',
#   'Terje Strømdahl',
#   'Øystein Røger',
#   'Marianne Jonger',
#   'Martin Karelius'],
#  ['Kofi Siriboe', 'Yootha Wong-Loi-Sing', 'Michael Ealy', 'Uzo Aduba'],
#  ['Pierce Brosnan',
#   'Luke Bracey',
#   'Olga Kurylenko',
#   'Eliza Taylor',
#   'Caterina Scorsone',
#   'Bill Smitrovich',
#   'Will Patton',
#   'Amila Terzimehic',
#   'Lazar Ristovski',
#   'Mediha Musliovic'],
#  ['Brigitte Kali Canales', 'Andrea Cortes', 'Julia Vera', 'Sal Lopez'],
#  ['David Oyelowo',
#   'Rosario Dawson',
#   'Lonnie Chavis',
#   'Amiah Miller',
#   'Alfred Molina',
#   'Maria Bello'],
#  ['Pat Sajak', 'Vanna White'],
#  ['Aishwarya Rajesh',
#   'Vidhu',
#   'Surya Ganapathy',
#   'Madhuri',
#   'Pavel Navageethan',
#   'Avantika Vandanapu'],
#  ['Aishwarya Rajesh',
#   'Vidhu',
#   'Surya Ganapathy',
#   'Madhuri',
#   'Pavel Navageethan',
#   'Avantika Vandanapu'],
#  ['Aishwarya Rajesh',
#   'Vidhu',
#   'Surya Ganapathy',
#   'Madhuri',
#   'Pavel Navageethan',
#   'Avantika Vandanapu'],
#  ['Aishwarya Rajesh',
#   'Vidhu',
#   'Surya Ganapathy',
#   'Madhuri',
#   'Pavel Navageethan',
#   'Avantika Vandanapu'],
#  ['Theo James',
#   'Mary McDonnell',
#   'Lara Pulver',
#   'Graham McTavish',
#   'Tom Canton',
#   'David Errigo Jr',
#   'Jennifer Hale',
#   'Kari Wahlgren',
#   'Matt Yang King',
#   'Darryl Kurylo',
#   'Keith Ferguson'],
#  ['Melissa Roxburgh',
#   'Josh Dallas',
#   'Athena Karkanis',
#   'J.R. Ramirez',
#   'Luna Blaise',
#   'Jack Messina',
#   'Parveen Kaur'],
#  ['Lucía Uribe',
#   'Flavio Medina',
#   'Isabella Vazquez Morales',
#   'Pierre Louis',
#   'Mercedes Hernández'],
#  ['Ahmed El Fishawy',
#   'Ruby',
#   'Mohamed Mamdouh',
#   'Ahmed Malek',
#   'Asmaa Abulyazeid',
#   'Samy Maghawry',
#   'Safaa El-Toukhy',
#   'Ahmed Kamal',
#   'Arfa Abdel Rassoul',
#   'Hana Shiha'],
#  ['Paik Jong-won'],
#  ['Roy Chiu',
#   'Ann Hsu',
#   'Tsai Chen-nan',
#   'Chung Hsin-ling',
#   'Lan Wei-hua',
#   'Peace Yang',
#   'Huang Lu Tz-yin'],
#  ['Jason Momoa',
#   'Isabela Merced',
#   'Manuel Garcia-Rulfo',
#   'Amy Brenneman',
#   'Adria Arjona',
#   'Raza Jaffrey',
#   'Justin Bartha',
#   'Lex Scott Davis',
#   'Michael Raymond-James'],
#  ['Sandra Oh',
#   'Jay Duplass',
#   'Holland Taylor',
#   'David Morse',
#   'Bob Balaban',
#   'Nana Mensah',
#   'Everly Carganilla'],
#  ['Asher Bishop',
#   'David Tennant',
#   'Michelle Gomez',
#   'Jill Talley',
#   'Brian Stepanek',
#   'Catherine Taber',
#   'Liliana Mumy',
#   'Nika Futterman',
#   'Cristina Pucelli',
#   'Jessica DiCicco',
#   'Grey Griffin',
#   'Lara Jill Miller'],
#  ['Paolo Contis',
#   'Yen Santos',
#   'Hans Tórgarð',
#   'Ruby Ruiz',
#   'Zweden Obias',
#   'Maria Rianne Castro',
#   'Arianne Mavis Uera',
#   'Maricor Canlas'],
#  ['Anton Yelchin',
#   'Felicity Jones',
#   'Jennifer Lawrence',
#   'Charlie Bewley',
#   'Alex Kingston',
#   'Oliver Muirhead',
#   'Finola Hughes',
#   'Chris Messina',
#   'Ben York Jones',
#   'Jamie Thomas King'],
#  ['Philip Froissant',
#   'Alice Dwyer',
#   'Hanns Zischler',
#   'Mercedes Müller',
#   'Sammy Scheuritzel',
#   'Lieselotte Voß',
#   'Katharina Schütz',
#   'Jodie Leslie Ahlborn',
#   'Marco Wittorf',
#   'Ilknur Boyraz'],
#  ['Arvind Swamy', 'Manisha Koirala', 'Nasser', 'Raja Krishnamoorthy'],
#  ['Alan C. Lim',
#   'Paul Killam',
#   'Maisie Benson',
#   'Kerry Gudjohnsen',
#   'Smith Foreman',
#   'Neena-Sinaii Simpo',
#   'Eli Morse',
#   'Adelaide Hirasaki',
#   'Jim Capobianco',
#   'Anna Chambers',
#   'Pfifer Chastain'],
#  ['Idia Aisien',
#   'Ndidi Obi',
#   'Kenneth Okolie',
#   'Zack Orji',
#   'Bovi Ugboma',
#   'Bimbo Ademoye',
#   'Beverly Osu',
#   'Beverly Naya',
#   'Larry Gaaga',
#   'Shaffy Bello',
#   'Chioma Chukwuka Akpotha',
#   'Waje'],
#  ['Dulquer Salmaan',
#   'Nithya Menon',
#   'Prakash Raj',
#   'Leela Samson',
#   'Vinodhini',
#   'Ramya Subramanian',
#   'Siva Ananth',
#   'John Devasahayam',
#   'Prabhu Lakshman'],
#  ['Ludovica Francesconi',
#   'Giuseppe Maggio',
#   'Gaja Masciale',
#   'Jozef Gjura',
#   'Eleonora Gaggero',
#   'Franco Ravera',
#   'Elisabetta Coraini',
#   'Michele Franco',
#   'Edoardo Rossi'],
#  ['Anmol Limbu',
#   'Ishika Gurung',
#   'Manju Chettri',
#   'Banita Lagun',
#   'Binod Pradhan',
#   'Mahindra Bajgai',
#   'Rupa Tamang',
#   'Saran Rai'],
#  ['Taylor Kitsch',
#   'Nina Hoss',
#   'Logan Marshall-Green',
#   'Michael C. Hall',
#   'Tuppence Middleton',
#   'Mala Emde',
#   'Maximilian Ehrenreich',
#   'Sebastian Koch',
#   'Anne Ratte-Polle',
#   'Lena Dörrie',
#   'Benjamin Sadler'],
#  ['Larissa Manoela',
#   'Thati Lopes',
#   'Bruno Montaleone',
#   'David Sherod James',
#   'Maiara Walsh',
#   'Flávia Garrafa',
#   'Kathy-Ann Hart',
#   'Ray Faiola',
#   'Noa Graham'],
#  ['Elizabeth Banks',
#   'James Marsden',
#   'Gillian Jacobs',
#   'Sarah Wright',
#   'Ethan Suplee',
#   'Bill Burr',
#   'Ken Davitian',
#   'Lawrence Gilliard Jr.',
#   'Alphonso Mcauley',
#   "Da'Vone McDonald",
#   'John Marsden',
#   'Willie Garson',
#   'Oliver Hudson',
#   'P.J. Byrne'],
#  ['Kaito Ishikawa',
#   'Asami Seto',
#   'Nao Toyama',
#   'Atsumi Tanezaki',
#   'Maaya Uchida',
#   'Yurika Kubo',
#   'Inori Minase'],
#  ['Holly Hunter',
#   'Harvey Keitel',
#   'Sam Neill',
#   'Anna Paquin',
#   'Kerry Walker',
#   'Genevieve Lemon',
#   'Tungia Baker',
#   'Ian Mune'],
#  ['Matilda Lambert',
#   'Ik Ogbonna',
#   'Prince Sontoye',
#   'Blossom Chukwujekwu',
#   'Linda Osifo',
#   'Emem Inwang',
#   'Pete Edochie',
#   'Shaffy Bello',
#   'Okon Imeh  Bishop',
#   'Chinenye Nnebe',
#   'Femi Adebayo'],
#  ['Liza Jacqueline',
#   'Helena Evangeliou',
#   'Lisa Ortiz',
#   'Kerry Williams',
#   'Gregory Abbey',
#   'Dan Green',
#   'Michael Sinterniklaas',
#   'Suzy Myers',
#   'Christina Rodriguez',
#   'Dani Schaffel',
#   'Sebastian Arcelus',
#   'Rachael Lillis'],
#  ['John David Washington',
#   'Boyd Holbrook',
#   'Alicia Vikander',
#   'Vicky Krieps',
#   'Lena Kitsopoulou',
#   'Panos Koronis',
#   'Maria Votti'],
#  ['Rosa Salazar',
#   'Eric Lange',
#   'Catherine Keener',
#   'Jeff Ward',
#   'Manny Jacinto',
#   'Hannah Levien',
#   'Patrick Fischler'],
#  ['Tyler Posey',
#   'Charlet Chung',
#   'Jorge Diaz',
#   'Camille Ramsey',
#   'Luke Youngblood',
#   'Renée Elise Goldsberry'],
#  ['Finnegan Oldfield',
#   'Nicolas Duvauchelle',
#   'Guillaume Gouix',
#   'Garance Marillier',
#   'Nailia Harzoune'],
#  ['Jane Fonda',
#   'Lily Tomlin',
#   'Martin Sheen',
#   'Sam Waterston',
#   'June Diane Raphael',
#   'Brooklyn Decker',
#   'Ethan Embry',
#   'Baron Vaughn'],
#  ['Chino Darín',
#   'Nancy Dupláa',
#   'Joaquín Furriel',
#   'Peter Lanzani',
#   'Mercedes Morán',
#   'Diego Peretti',
#   'Vera Spinetta',
#   'Nico García Hume',
#   'Victoria Almeida',
#   'Santiago Korovsky',
#   'Patricio Aramburu',
#   'Alfonso Tort',
#   'Diego Gentile',
#   'Néstor Guzzini',
#   'Daniel Kuzniecka'],
#  ['Diana Gómez',
#   'Silma López',
#   'Paula Malia',
#   'Teresa Riott',
#   'Maxi Iglesias',
#   'Ibrahim Al Shami'],
#  ['Andria Tayeh',
#   "Rakeen Sa'ad",
#   'Noor Taher',
#   'Yara Mustafa',
#   'Joanna Arida',
#   'Salsabiela',
#   'Nadera Emran',
#   'Reem Saadeh'],
#  ['Lokillo Florez'],
#  ['Ben Rausch',
#   'Erica Lindbeck',
#   'Dante Basco',
#   'Brando Eaton',
#   'Stephen Kramer Glickman',
#   'Caroline Caliston',
#   'G.K. Bowes',
#   'Dan McCoy'],
#  ['Mike Ezuruonye',
#   'Juliet Ochienge',
#   'Angela Okorie',
#   'Huddah Monroe',
#   'Catherine Kamau',
#   'Naomi Mburu',
#   'Derrick Aduwo',
#   'Chris Kamau',
#   'Abubakar Salum',
#   'Celebrity Landlord'],
#  ['Ximena Romo',
#   'Mabel Cadena',
#   'Alejandra Herrera',
#   'Nelly González',
#   'Samantha Orozco',
#   'Axel Arenas',
#   'Esteban Caicedo',
#   'Paulina Goto',
#   'Raquel Robles',
#   'Baby Bátiz',
#   'Pascacio López',
#   'Juán Carlos Torres',
#   'Javier Oliván',
#   'Claudia Lobo',
#   'Giovanna Zacarías'],
#  ['Joey King',
#   'Joel Courtney',
#   'Jacob Elordi',
#   'Molly Ringwald',
#   'Taylor Zakhar Perez',
#   'Maisie Richardson-Sellers',
#   'Meganne Young',
#   'Stephen Jennings'],
#  ['Colin Firth',
#   'Nicole Kidman',
#   'Jeremy Irvine',
#   'Stellan Skarsgård',
#   'Sam Reid',
#   'Hiroyuki Sanada',
#   'Michael MacKenzie',
#   'Tom Stokes'],
#  ['Laila Lockhart Kraner',
#   'Tucker Chandler',
#   'Juliet Donenfeld',
#   'Maggi Lowe',
#   'Donovan Patton',
#   'Eduardo Franco',
#   'Tara Strong',
#   'Secunda Wood',
#   'Carla Tassara',
#   'Sainty Nelsen'],
#  ['Khemanit Jamikorn',
#   'Thitipoom Techaapaikhun',
#   'Kannaporn Puangthong',
#   'Premmanat Suwannanon',
#   'Mintita Wattanakul',
#   'Thames Sanpakit',
#   'Katareeya Theapchatri',
#   'Phanuroj Chalermkijporntavee',
#   'Jirapisit Jaravijit'],
#  ['Amparo Grisales',
#   'Fernando Solórzano',
#   'Angelica Blandon',
#   'Katherine Escobar',
#   'Yuly Ferreira',
#   'Alejandra Sandoval',
#   'Andrea Gómez',
#   'Andrea Guzmán',
#   'Diego Vásquez',
#   'Julián Román',
#   'Juan Pablo Franco'],
#  ['Yeo Jin-goo',
#   'Lee Se-young',
#   'Kim Sang-kyung',
#   'Jung Hye-young',
#   'Jang Kwang',
#   'Kwon Hae-hyo',
#   'Jang Yeong-nam',
#   'Lee Kyu-han'],
#  ['Yoko Hikasa',
#   'Katsuyuki Konishi',
#   'Megumi Hayashibara',
#   'Inuko Inuyama',
#   'Romi Park',
#   'Kosuke Takaguchi',
#   'Masahiko Tanaka',
#   'Wataru Takagi',
#   'Yuji Ueda',
#   'Megumi Nakajima',
#   'Takehito Koyasu',
#   'Yoko Soumi',
#   'Motoko Kumai',
#   'Yui Horie',
#   'Yuichi Nakamura',
#   'Nana Mizuki',
#   'Takumu Miyazono',
#   'Noriaki Kanze',
#   'Michiko Neya',
#   'Toru Sakurai',
#   'Rina Hidaka',
#   'Masakazu Morita',
#   'Minami Takayama'],
#  ['Maggie Smith',
#   'Tom Courtenay',
#   'Billy Connolly',
#   'Pauline Collins',
#   'Michael Gambon',
#   'Andrew Sachs',
#   'Sheridan Smith',
#   'David Ryall',
#   'Trevor Peacock',
#   'Gwyneth Jones'],
#  ['Enhle Mbali',
#   'Ramsey Nouah',
#   'Dawn Thandeka Kang',
#   'Idris Sultan',
#   'Tumi Morake',
#   'Trevor Gumbi',
#   'Lillian Dube',
#   'Kaly Bossy Asante',
#   'Shaleen Surtie',
#   'Fabian Lojege'],
#  ['Hikaru Iwamoto',
#   'Tatsuya Fukazawa',
#   'Raul',
#   'Shota Watanabe',
#   'Koji Mukai',
#   'Ryohei Abe',
#   'Ren Meguro',
#   'Ryota Miyadate',
#   'Daisuke Sakuma',
#   'Arata Sato',
#   'Tatsuya Kageyama',
#   'Taiga Suzuki',
#   'Shunsuke Motoi',
#   'Taiga Tsubaki',
#   'Yuki Yokohara',
#   'Minato Matsui',
#   'Shosei Oda'],
#  ['Alain Uy',
#   'Ron Yuan',
#   'Mykel Shannon Jenkins',
#   'Jae Suh Park',
#   'Matthew Page',
#   'Joziah Lagonoy',
#   'Raymond Ma'],
#  ['Lior Raz',
#   'Kaelen Ohm',
#   'Sanaa Lathan',
#   'Moran Rosenblatt',
#   'Lior Ashkenazi',
#   'Gregg Henry',
#   'Gal Toren'],
#  ['Suriya',
#   'Vijay Sethupathi',
#   'Revathy',
#   'Prakash Raj',
#   'Siddarth',
#   'Parvathy',
#   'Delhi Ganesh',
#   'Gautham Vasudev Menon',
#   'Anjali',
#   'Yogi Babu',
#   'Aditi Balan',
#   'Remya Nambeesan',
#   'Poorna',
#   'Prayaga Martin',
#   'Rythvika Suriya',
#   'Arvind Swamy',
#   'Prasanna',
#   'Atharva',
#   'Bobby Simha',
#   'Ashok Selvan',
#   'Nedumudi Venu',
#   'Kishore'],
#  ['Falz',
#   'Nse Ikpe-Etim',
#   'Williams Uchemba',
#   'Toni Tones',
#   'Michelle Dede',
#   'Karibi Fubara',
#   'Buchi Ojei',
#   'Jemima Osunde',
#   'Blossom Chukwujekwu',
#   'Gbubemi Ejeye',
#   'Badmus Olakunle'],
#  ['Suliane Brahim',
#   'Sofian Khammes',
#   'Marie Narbonne',
#   'Raphaël Romand',
#   'Stéphan Castang',
#   'Victor Bonnel',
#   'Christian Bouillette',
#   'Renan Prévot',
#   'Vincent Deniard'],
#  ['Lin-Manuel Miranda',
#   'Ynairaly Simo',
#   'Zoe Saldana',
#   'Juan de Marcos',
#   'Brian Tyree Henry',
#   'Gloria Estefan',
#   'Michael Rooker',
#   'Nicole Byer'],
#  ['Shah Rukh Khan',
#   'Deepika Padukone',
#   'Nikitin Dheer',
#   'Satyaraj',
#   'Kamini Kaushal',
#   'Lekh Tandon',
#   'Mukesh Tiwari'],
#  ['Luis Brandoni',
#   'China Zorrilla',
#   'Antonio Gasalla',
#   'Julio De Grazia',
#   'Betiana Blum',
#   'Monica Villa',
#   'Juan Manuel Tenuta',
#   'Andrea Tenuta',
#   'Cecilia Rossetto',
#   'Enrique Pinti'],
#  ['Jackie Collins'],
#  ['Fernán Mirás',
#   'Cecilia Dopazo',
#   'Imanol Arias',
#   'Héctor Alterio',
#   'Leonardo Sbaraglia',
#   "Federico D'Elía",
#   'David Masajnik',
#   'Cristina Banegas',
#   'Ernesto Alterio',
#   'Antonio Birabent'],
#  ['Ramsey Nouah',
#   'Rita Dominic',
#   'Chidi Mokeme',
#   'Ibinabo Fiberesima',
#   'Daniel K. Daniel',
#   'Memry Savanhu',
#   'Adonijah Owiriwa',
#   'Pat Nebo',
#   'Nelly Ekwereogu',
#   'Shuaibu Ebenesi Adams',
#   'Debo Oguns',
#   'Ben Nwosu',
#   'Ada Ofoegbu'],
#  ['Ashley Greene',
#   'Shawn Ashmore',
#   'Sharif Atkins',
#   'Britt Baron',
#   'Diana Hopper',
#   'Ross McCall',
#   'Jamie Kaler',
#   'Travis Coles',
#   'Susan Walters',
#   'Jason Liles'],
#  ['David Geffen'],
#  ['Mark Towle',
#   'Shawn Pilot',
#   'Constance Nunes',
#   'Tony Quinones',
#   'Mike "Caveman" Pyle'],
#  ['Ana Valeria Becerril',
#   'Michael Ronda',
#   'Yankel Stevan',
#   'Zion Moreno',
#   'Luis Curiel',
#   'Samantha Acuña',
#   'Macarena García',
#   'Fiona Palomo',
#   'Andrés Baida',
#   'Patricio Gallardo',
# ...
#   'José Carlos Ruiz',
#   'Gabriel Nuncio',
#   'Rosa María Bianchi',
#   'Héctor Bonilla',
#   'Andrés Almeida'],
#  ['Giuseppe Dave Seke',
#   'Haroun Fall',
#   'Beatrice Grannò',
#   'Dylan Magon',
#   'Daniela Scattolin',
#   'Madior Fall',
#   'Virgina Diop'],
#  ['Izzy Bee', 'Ali Bee', 'Tim Bee'],
#  ['Sourav Chakraborty', 'Mayur Vyas', 'Anil Datt'],
#  ['Sourav Chakraborty',
#   'Vidit Kumar',
#   'Mayur Vyas',
#   'Mahendra Bhatnagar',
#   'Dishi Duggal',
#   'Nandkishore Pandey'],
#  ['Sourav Chakraborty', 'Anil Dutt'],
#  ['Shailendra Pandey',
#   'Vinod Kulkarni',
#   'Rohan',
#   'Mukesh Pandey',
#   'Bhakti Shalini',
#   'Ghanshyam Shukla',
#   'Pankaj Kalra',
#   'Kanchan',
#   'Sanchit Wartak',
#   'Ajay Singhal'],
#  ['Shailendra Pandey',
#   'Rohan',
#   'Mukesh Pandey',
#   'Bhakti',
#   'Shalini',
#   'Ghanshyam Shukla',
#   'Sabina Malik'],
#  ['Diego Boneta',
#   'Juan Pablo Zurita',
#   'Camila Sodi',
#   'Óscar Jaenada',
#   'Izan Llunas',
#   'Paulina Dávila',
#   'Martín Bello',
#   'Anna Favella',
#   'César Bordón',
#   'Vanessa Bauche'],
#  ['Jessica Chastain',
#   'Mark Strong',
#   'Gugu Mbatha-Raw',
#   'Michael Stuhlbarg',
#   'Raoul Bhaneja',
#   'John Lithgow',
#   'Sam Waterston',
#   'Chuck Shamata',
#   'Jake Lacy',
#   'Alison Pill',
#   'David Wilson Barnes'],
#  ['Jacob Ewaniuk', 'Kyle Breitkopf', 'Addison Holley'],
#  ['Edward James Olmos',
#   'William Forsythe',
#   'Pepe Serna',
#   'Danny De La Paz',
#   'Evelina Fernandez',
#   'Cary-Hiroyuki Tagawa',
#   'Daniel Villarreal',
#   'Sal Lopez',
#   'Daniel Haro',
#   'Domingo Ambriz'],
#  ['Imran Khan',
#   'Vir Das',
#   'Kunaal Roy Kapur',
#   'Poorna Jagannathan',
#   'Shenaz Treasury',
#   'Vijay Raaz',
#   'Paresh Ganatra',
#   'Rahul Singh'],
#  ['Aamir Khan',
#   'Monica Dogra',
#   'Kriti Malhotra',
#   'Prateik Babbar',
#   'Aasha Pawar',
#   'Jyoti Pawar',
#   'Norma Lobo',
#   'Kitu Gidwani',
#   'Danish Husain',
#   'Jehan Manekshaw'],
#  ['Imran Khan',
#   "Genelia D'Souza",
#   'Manjari Fadnis',
#   'Ayaz Khan',
#   'Prateik Babbar',
#   'Ratna Pathak Shah',
#   'Arbaaz Khan',
#   'Sohail Khan'],
#  ['Aamir Khan',
#   'Gracy Singh',
#   'Rachel Shelley',
#   'Paul Blackthorne',
#   'Kulbhushan Kharbanda',
#   'Raghuvir Yadav',
#   'Yashpal Sharma',
#   'Rajendranath Zutshi',
#   'Rajesh Vivek',
#   'Aditya Lakhia'],
#  ['Aamir Khan', 'Ashutosh Gowariker'],
#  ['Omkar Das Manikpuri',
#   'Raghuvir Yadav',
#   'Malaika Shenoy',
#   'Nawazuddin Siddiqui',
#   'Naseeruddin Shah',
#   'Sitaram Panchal',
#   'Shalini Vatsa',
#   'Farrukh Jaffar',
#   'Aamir Bashir',
#   'Vishal Om Prakash'],
#  ['Aamir Khan',
#   'Darsheel Safary',
#   'Tanay Chheda',
#   'Tisca Chopra',
#   'Vipin Sharma',
#   'Girija Oak',
#   'M.K. Raina'],
#  ['Fatima Sana Shaikh',
#   'Jaideep Ahlawat',
#   'Armaan Ralhan',
#   'Nushrat Bharucha',
#   'Abhishek Banerjee',
#   'Inayat Verma',
#   'Konkona Sen Sharma',
#   'Aditi Rao Hydari',
#   'Shefali Shah',
#   'Manav Kaul',
#   'Tota Roy Chowdhury'],
#  ['Michael J. Woodard',
#   'Mary Lambert',
#   'Brett Gelman',
#   'Jonathan Van Ness',
#   'Tony Hale',
#   'Haley Tju',
#   'Annie Potts',
#   'Vincent Rodriguez III',
#   'Flea',
#   'Jennifer Coolidge'],
#  ['Jonah Wineberg',
#   'Margarita Valderrama',
#   'Deven Christian Mack',
#   'Jaimee Joe Gonzaga',
#   'Sharjil Rasool',
#   'Will Bowes',
#   'Jason Deline',
#   'Dan Petronijevic',
#   'Carling Doubt',
#   'Joshua Graham',
#   'Cory Doran'],
#  ['America Young',
#   'Cassidy Naber',
#   'Kirsten Day',
#   'Cassandra Morris',
#   'Lisa Fuson',
#   'Greg Chun',
#   'Benjamin Pronsky',
#   'Laila Berzins',
#   'Nakia Burrise',
#   'Jacob Craner'],
#  ['Mia Wasikowska',
#   'Jessica Chastain',
#   'Tom Hiddleston',
#   'Charlie Hunnam',
#   'Jim Beaver',
#   'Burn Gorman',
#   'Leslie Hope',
#   'Doug Jones',
#   'Jonathan Hyde',
#   'Bruce Gray'],
#  ['David Spade',
#   'London Hughes',
#   'Fortune Feimster',
#   'Jamie Foxx',
#   'David Alan Grier',
#   'Kyla-Drew',
#   'Porscha Coleman',
#   'Jonathan Kite',
#   'Corinne Foxx'],
#  ['Isaiah Washington',
#   'Vivica A. Fox',
#   'Jimmy Jean-Louis',
#   'Genevieve Nnaji',
#   'Stephanie Okereke',
#   'Justus Esiri',
#   'Ebbe Bassey',
#   'Jon Freda',
#   'Evan Brinkman'],
#  ['Alexa Ilacad',
#   'Charlie Dizon',
#   'Gillian Vicencio',
#   'Belle Mariano',
#   'Dominic Ochoa',
#   'Carmina Villaroel',
#   'Irma Adlawan',
#   'Kakai Bautista',
#   'Cai Cortez',
#   'Jameson Blake',
#   'Joao Constancia',
#   'Jeremiah Lisbo',
#   'Clarence Delgado',
#   'Pinky Amador',
#   'Minnie Aguilar',
#   'Gigi De Lana',
#   'Toni Gonzaga',
#   'Bea Alonzo',
#   'Angel Locsin',
#   'Shaina Magdayao',
#   'Enchong Dee'],
#  ['Alexandra Pfeifer',
#   'Yalany Marschner',
#   'Trystan Pütter',
#   'Helen Schneider',
#   'Julius Nitschkoff',
#   'Dennis Kyere',
#   'Ina Geraldine Guy',
#   'Katrin Pollitt',
#   'Julia Strowski',
#   'Anton Wichers'],
#  ['Seo Jang-hoon', 'Kim Sook', 'Han Hye-jin', 'Kwak Jung-eun', 'Ju Wu-jae'],
#  ['Chris Hemsworth',
#   'Daniel Brühl',
#   'Olivia Wilde',
#   'Alexandra Maria Lara',
#   'Pierfrancesco Favino',
#   'David Calder',
#   'Natalie Dormer',
#   'Stephen Mangan',
#   'Christian McKay',
#   'Alistair Petrie'],
#  ['Anthony Mackie',
#   'Jamie Dornan',
#   'Katie Aselton',
#   'Ally Ioannides',
#   'Ramiz Monsef',
#   'Bill Oberst Jr.'],
#  ['Jessica Chastain',
#   'Johan Heldenbergh',
#   'Daniel Brühl',
#   'Timothy Radford',
#   'Efrat Dor',
#   'Iddo Goldberg',
#   'Shira Haas',
#   'Michael McElhatton',
#   'Val Maloku',
#   'Goran Kostic'],
#  ['Andrew Wilson',
#   'Cassidy Gifford',
#   'Brianne Howey',
#   'Reiley McClendon',
#   'Olivia Draguicevich',
#   'Max Wright',
#   'Hans Marrero',
#   'Rich Skidmore',
#   'Chris Sturgeon',
#   'Gopal Bidari'],
#  ['Anmol Thakeria Dhillon',
#   'Jhataleka',
#   'Niki Walia',
#   'Kamini Khanna',
#   'Zoa Morani',
#   'Nayan Shukla',
#   'Eklavyey Kashyap',
#   'Reem Shaikh'],
#  ['Uneek', 'Mighty Mark', 'Tsu Terry', 'TT The Artist'],
#  ['Toshiyuki Toyonaga',
#   'Miyuki Sawashiro',
#   'Mamoru Miyano',
#   'Kana Hanazawa',
#   'Hiroshi Kamiya',
#   'Daisuke Ono',
#   'Jun Fukuyama',
#   'Yuichi Nakamura',
#   'Yuki Kaji',
#   'Ayahi Takagaki',
#   'Kazuma Horie',
#   'Sanae Kobayashi',
#   'Takaya Kuroda',
#   'Kari Wahlgren',
#   'Darrel Guilbeau',
#   'Bryce Papenbrook',
#   'Michelle Ruff',
#   'Johnny Yong Bosch',
#   'Crispin Freeman',
#   'Yuri Lowenthal',
#   'Steve Blum'],
#  ['Daisuke Ono',
#   'M・A・O',
#   'Tomohiro Kaku',
#   'Saori Hayami',
#   'Shuichi Ikeda',
#   'Kendo Kobayashi',
#   'Razor Ramon RG',
#   'Razor Ramon HG',
#   'Masane Tsukayama',
#   'Masaya Onosaka',
#   'Kenjiro Tsuda',
#   'Teruaki Ogawa',
#   'Hisanori Yoshida',
#   'Yuki Kaji'],
#  ['Garth Brooks'],
#  ['Lauren Graham',
#   'Alexis Bledel',
#   'Scott Patterson',
#   'Keiko Agena',
#   'Yanic Truesdale',
#   'Kelly Bishop',
#   'Edward Herrmann',
#   'Melissa McCarthy',
#   'Sean Gunn',
#   'Liza Weil',
#   'Liz Torres',
#   'Jared Padalecki'],
#  ['Haruka Shiraishi',
#   'Shiki Aoki',
#   'Akira Sekine',
#   'Junya Enoki',
#   'Yuuichirou Umehara',
#   'Megumi Ogata',
#   'Shoya Chiba',
#   'Makoto Furukawa',
#   'Seiro Ogino',
#   'Koji Yusa',
#   'Chika Anzai',
#   'Asami Seto',
#   'Shizuka Ito',
#   'Juri Kimura',
#   'Kaito Ishikawa',
#   'Yoko Hikasa',
#   'Jun Fukuyama'],
#  ['Tan France', 'Alexa Chung'],
#  ['Amber Midthunder',
#   'Brett Zimmerman',
#   'Chris Browning',
#   'Walter Fauntleroy',
#   'Claudia Ferri',
#   'Lorenzo James Henrie',
#   'Ellen Wroe',
#   'Ashley Holliday Tavares',
#   'Nancy Linehan Charles',
#   'Jonna Walsh'],
#  ['Ward El Kal',
#   'Aimée Sayah',
#   'Bassem Moughnie',
#   'Carlos Azar',
#   'Sara Abi Kanaan',
#   'Wesam Hanna'],
#  ['Kieran Walton',
#   'Carlos Salazar',
#   'Greg Chun',
#   'Jamieson Price',
#   'Reba Buhr',
#   'Todd Haberkorn',
#   'Landon McDonald',
#   'Scott Whyte',
#   'Paul Haapaniemi'],
#  ['Max Fincham',
#   'Twinkle Jaiswal',
#   'Bradley Bissett',
#   'Dylan Naden',
#   'Adam Longworth',
#   'Ashton Frank',
#   'Edward Moloney',
#   'Esther Coles',
#   'Jess Robinson',
#   'Miranda Pointer',
#   'Osian Thompson',
#   'Simon Lipkin',
#   'Richard David-Caine'],
#  ['Kiko Mizuhara',
#   'Honami Sato',
#   'Yoko Maki',
#   'Anne Suzuki',
#   'Tetsushi Tanaka',
#   'Sara Minami',
#   'Yui Uemura',
#   'Shinya Niiro',
#   'Shunsuke Tanaka',
#   'Setsuko Karasuma'],
#  ['Junichi Kanemaru',
#   'Sanae Kobayashi',
#   'Ryo Hirohashi',
#   'Taeko Kawata',
#   'Nobutoshi Canna',
#   'Koji Yusa',
#   'Rumi Ochiai',
#   'Sayaka Aoki',
#   'Chikao Otsuka'],
#  ['Joaquin Phoenix',
#   'Philip Seymour Hoffman',
#   'Amy Adams',
#   'Laura Dern',
#   "Kevin J. O'Connor",
#   'Jesse Plemons',
#   'Rami Malek',
#   'Christopher Evan Welch',
#   'Madisen Beaty',
#   'Ambyr Childers',
#   'Price Carson'],
#  ["Nasir 'Nas' Jones",
#   'Busta Rhymes',
#   'Pete Rock',
#   'Pharrell Williams',
#   'Q-Tip',
#   'Swizz Beatz',
#   'Alicia Keys',
#   'DJ Premier'],
#  ['Isyana Sarasvati',
#   'Kunto Aji',
#   'Sisir Tanah',
#   'Chiki Fawzi',
#   'ARAH',
#   'Hindia',
#   'Ardhito Pramono',
#   'Rio Dewanto',
#   'Angga Dwimas Sasongko',
#   'Rachel Amanda'],
#  ['Daniel Valdez',
#   'Edward James Olmos',
#   'Charles Aidman',
#   'Tyne Daly',
#   'John Anderson',
#   'Abel Franco',
#   'Mike Gomez',
#   'Francis X. McCarthy',
#   'Alma Martínez',
#   'Lupe Ontiveros',
#   'Tony Plana'],
#  ['Jamie Foxx',
#   'David Alan Grier',
#   'Kyla-Drew',
#   'Porscha Coleman',
#   'Jonathan Kite',
#   'Heather Hemmens',
#   'Valente Rodriguez'],
#  ['Abigail Cowen',
#   'Hannah Van Der Westhuysen',
#   'Precious Mustapha',
#   'Eliot Salt',
#   'Elisha Applebaum',
#   'Danny Griffin',
#   'Sadie Soverall',
#   'Freddie Thorp',
#   'Rob James-Collier',
#   'Eve Best',
#   'Lesley Sharp'],
#  ['Kevin Spacey',
#   'Robin Wright',
#   'Kate Mara',
#   'Corey Stoll',
#   'Sakina Jaffrey',
#   'Kristen Connolly',
#   'Constance Zimmer',
#   'Sebastian Arcelus',
#   'Nathan Darrow',
#   'Sandrine Holt',
#   'Michel Gill',
#   'Elizabeth Norment',
#   'Mahershala Ali',
#   'Reg E. Cathey',
#   'Molly Parker',
#   'Derek Cecil',
#   'Elizabeth Marvel',
#   'Kim Dickens',
#   'Lars Mikkelsen',
#   'Michael Kelly',
#   'Joel Kinnaman',
#   'Campbell Scott',
#   'Patricia Clarkson',
#   'Neve Campbell'],
#  ['Kim Myung-min',
#   'Kim Beom',
#   'Ryu Hye-young',
#   'Lee Jung-eun',
#   'Park Hyuk-kwon',
#   'An Nae-sang',
#   'Chung Won-joong',
#   'Lee Su-kyoung',
#   'Lee David',
#   'Go Youn-jung',
#   'Hyunwoo'],
#  ['Paul Rudd', 'Aisling Bea', 'Desmin Borges', 'Zoë Chao', 'Karen Pittman'],
#  ['Kim Hye-su',
#   'Lee Je-hoon',
#   'Cho Jin-woong',
#   'Jang Hyun-sung',
#   'Jeong Hae-gyoon',
#   'Kim Won-hae',
#   'Jung Han-bi',
#   'Lee Yu-jun',
#   'Son Hyeon-ju'],
#  ['Katie McGrath',
#   'Brandon Jay McLaren',
#   'Steve Byers',
#   'Patrick Garrow',
#   'Dean McDermott',
#   'Christopher Jacot',
#   'Wendy Crewson',
#   'Leslie Hope',
#   'Lovell Adams-Gray',
#   'Jim Watson',
#   'Paulino Nunes',
#   'Ty Olsson',
#   'Joanne Vannicola',
#   'Sebastian Pigott',
#   'Madison Cheeatow',
#   'Melinda Shankar',
#   'Kaitlyn Leeb',
#   'Rebecca Liddiard',
#   'Paula Brancati',
#   'Salvatore Antonio',
#   'Lisa Berry',
#   'Gabriel Darku',
#   'Erin Karpluk',
#   'Mercedes Morris',
#   'Ilan Muallem',
#   'Baraka Rahmani',
#   'Rosie Simon',
#   'Robert Cormier'],
#  ['Chang Chen',
#   'Janine Chang',
#   'Christopher Lee',
#   'Anke Sun',
#   'Lin Hui-min',
#   'Samuel Ku',
#   'Zhang Bojia',
#   'Lu Hsueh-feng'],
#  ['Nannaphas Loetnamchoetsakun',
#   'Praewa Suthamphong',
#   'Sumitra Duangkaew',
#   'Tanutchai Wijitvongtong',
#   'Tarisa Preechatangkit',
#   'Natticha Chantaravareelekha',
#   'Miori Ohkubo',
#   'Pakwan Noijaiboon',
#   'Napaphat Worraphuttanon',
#   'Vathusiri Phuwapunyasiri',
#   'Rinrada Inthaisong',
#   'Suchaya Saenkhot',
#   'Mananya Kaoju',
#   'Kandis Wanarun',
#   'Ekapol Deebunmee',
#   'Panta Pattanaampaiwong',
#   'Rachaya Tupkunanon',
#   'Supasawad Buranawech',
#   'Thitirat Rojsangrat',
#   'Sawanee Utoomma',
#   'Phattharanarin Mueanarit',
#   'Chanyapuk Numprasop'],
#  ['Panja Vaisshnav Tej', 'Krithi Shetty', 'Vijay Sethupathi'],
#  ['Saurav Chakraborty',
#   'Sankalp Rastogi',
#   'Anamaya Varma',
#   'Aditya Raaj',
#   'Manoj Pandey'],
#  ['Saurav Chakraborty',
#   'Ganesh Diweker',
#   'Arpita Vora',
#   'Manoj Pandey',
#   'Mayur Vyas',
#   'Sanjeev Tiwari',
#   'Nandkishore Pandey',
#   'Aditya Raaj'],
#  ['Saurav Chakraborty',
#   'Sanket Mhatre',
#   'Kamal Chaturvedi',
#   'Warren Dsouza',
#   'Trilok Patel',
#   'Manish Bhuvan'],
#  ['Saurav Chakraborty'],
#  ['Victor Rasuk',
#   'Nathalie Kelley',
#   'Dan Bucatinsky',
#   'David Del Rio',
#   'Michelle Veintimilla',
#   'Lisa Vidal',
#   'Carlos Gómez',
#   'Belissa Escobedo'],
#  ['Yang Tianxiang', 'Zhang He', 'Xuan Xiaoming', 'Li Shimeng'],
#  ['Brian Stepanek',
#   'Allison Munn',
#   'Aidan Gallagher',
#   'Casey Simpson',
#   'Mace Coronel',
#   'Lizzy Greene'],
#  ['Park Mi-sun', 'Jang Do-youn'],
#  ['Drew Barrymore',
#   'Michael Zegen',
#   'T.J. Miller',
#   'Holland Taylor',
#   'Ellie Kemper',
#   'Andrew Rannells',
#   'Michelle Buteau'],
#  ['Jiang Guangtao', 'Ma Zhengyang', 'Wen Sen', 'Hu Liangwei', 'Huang Ying'],
#  ['Um Tae-goo',
#   'Jeon Yeo-been',
#   'Cha Seoung-won',
#   'Lee Ki-young',
#   'Park Ho-san'],
#  ['Seun Ajayi',
#   'Zainab Balogun',
#   'Sammie Eddie',
#   'Linda Ejiofor',
#   'Charles Etubiebi',
#   'Shawn Faqua',
#   'Lord Frank',
#   'Ikubese Emmanuel Ifeanyi',
#   'Somkele Iyamah',
#   'Ali Nuhu',
#   'Wale Ojo'],
#  ['Rajkummar Rao',
#   'Varun Sharma',
#   'Janhvi Kapoor',
#   'Manav Vij',
#   'Sarita Joshi',
#   'Anuraag Arora',
#   "Alexx O'Nell",
#   'Rajesh Jais'],
#  ['Melissa McCarthy',
#   'Octavia Spencer',
#   'Jason Bateman',
#   'Bobby Cannavale',
#   'Pom Klementieff',
#   'Melissa Leo',
#   'Taylor Mosby',
#   'Marcella Lowery',
#   'Melissa Ponzio'],
#  ['Joey Bada$$', 'Andrew Howard', 'Zaria'],
#  ['Ardhito Pramono',
#   'Aurélie Moeremans',
#   'Arya Saloka',
#   'Roy Sungkono',
#   'Gilbert Pohan',
#   'Azizah Hanum',
#   'Tanta Ginting'],
#  ['Kenjiro Tsuda',
#   'Shizuka Ito',
#   'Kazuyuki Okitsu',
#   'M・A・O',
#   'Jun Fukushima',
#   'Kimiko Saito',
#   'Yoshimasa Hosoya',
#   'Masashi Nogawa',
#   'Junichi Yanagida',
#   'Hochu Otsuka',
#   'Atsuko Tanaka'],
#  ['Dolly Parton'],
#  ['Nick Wolfhard',
#   'Charles Demers',
#   'Montse Hernandez',
#   'Garland Whitt',
#   'Bruce Campbell',
#   "Catherine O'Hara",
#   'Brian Drummond',
#   'Giles Panton'],
#  ['Yogi Babu', 'Sheela Rajkumar', 'Sangili Murugan', 'G. M. Sundhar'],
#  ['Kang Quintus',
#   'Faith Fidel',
#   'Casson Chinepoh',
#   'Ramsey Nouah',
#   'Ndamo Damaris',
#   'Neba Godwill Awantu',
#   'Onyama Laura',
#   'Prince Sube',
#   'Daphne Nije',
#   'Zoe Elora Ebai Mayohchu'],
#  ['Ema Horvath',
#   'Trey Tucker',
#   'Mena Suvari',
#   'Haskiri Velazquez',
#   'Danny Corbo',
#   'Olan Montgomery',
#   'Troy Iwata'],
#  ['Rob Corddry',
#   'Brendan Fraser',
#   'Sarah Jessica Parker',
#   'William Shatner',
#   'Jessica Alba',
#   'Jane Lynch',
#   'George Lopez',
#   'Sofía Vergara',
#   'Craig Robinson',
#   'Ricky Gervais',
#   'Steve Zahn',
#   'Chris Parnell'],
#  ['Justin Long',
#   'Jonah Hill',
#   'Adam Herschman',
#   'Columbus Short',
#   'Maria Thayer',
#   'Lewis Black',
#   'Blake Lively',
#   'Mark Derwin',
#   'Ann Cusack',
#   'Robin Lord Taylor',
#   'Hannah Marks',
#   'Anthony Heald'],
#  ['Bruce Willis',
#   'Liu Ye',
#   'Song Seung-heon',
#   'William Chan Wai-ting',
#   'Fan Wei',
#   'Wu Gang',
#   'Ma Su',
#   'Janine Chang',
#   'Che Yongli',
#   'Feng Yuanzheng',
#   'Geng Le'],
#  ['Jade Pettyjohn',
#   'Kerris Dorsey',
#   'Nia Vardalos',
#   'Ian Ziering',
#   'Ysa Penarejo',
#   'Cathy Rigby',
#   'Kally Berard',
#   'Talia Pura',
#   'Paula Rivera',
#   'George Chiang'],
#  ['Idris Elba',
#   'Caleb McLaughlin',
#   'Jharrel Jerome',
#   'Byron Bowers',
#   'Lorraine Toussaint',
#   'Method Man',
#   'Ivannah Mercedes',
#   'Jamil Prattis',
#   'Liz Priestley'],
#  ['Brian Austin Green',
#   'Vinnie Jones',
#   'Lori Heuring',
#   'Richard Grieco',
#   'Patrick Durham',
#   'Tim Abell',
#   'Carson Lee Bradshaw',
#   'Manu Intiraymi',
#   'Danny Trejo'],
#  ['Zainab Balogun',
#   'Karibi Fubara',
#   'Diana Egwuatu',
#   'Richard Mofe-Damijo',
#   'Tina Mba',
#   'Onyeka Onwenu',
#   'Nkem Owoh',
#   'Patrick Diabuah',
#   'Ademola Adedoyin',
#   'Bikiya Graham Douglas'],
#  ['Fahadh Faasil', 'Soubin Shahir', 'Darshana Rajendran'],
#  ['Yolanthe Cabau',
#   'Noortje Herlaar',
#   'Kim-Lian van der Meij',
#   'Nienke Plas',
#   'Pip Pellens',
#   'Jim Bakkum',
#   'Huub Smit',
#   'Edwin Jonker'],
#  ['Karole Rocher',
#   'Garance Marillier',
#   'Roschdy Zem',
#   'Pierre Deladonchamps',
#   "Liah O'Prey",
#   'Paul Hamy',
#   'Mylène Jampanoï',
#   'Hafsia Herzi',
#   'Regina Anikiy',
#   'Annabelle Belmondo',
#   'Joséphine de La Baume'],
#  ['Emma Roberts',
#   'Kimberley Nixon',
#   'Juno Temple',
#   'Linzey Cocker',
#   'Sophie Wu',
#   'Alex Pettyfer',
#   'Georgia King',
#   'Natasha Richardson',
#   'Aidan Quinn',
#   'Lexi Ainsworth'],
#  ['Timothy Omundson',
#   'Thaila Ayala',
#   'Eric Bauza',
#   'Graham Verchere',
#   'Jordana Largy',
#   'Scott McNeil',
#   'Adrian Glynn McMorran',
#   'Chelsea Miller',
#   'Sean Tyson'],
#  ...]

# %%
df_netflix["cast"].dropna().str.split(', ')
# Out:
# 1       [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...
# 2       [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...
# 4       [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...
# 5       [Kate Siegel, Zach Gilford, Hamish Linklater, ...
# 6       [Vanessa Hudgens, Kimiko Glenn, James Marsden,...
#                               ...
# 8801    [Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri,...
# 8802    [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...
# 8804    [Jesse Eisenberg, Woody Harrelson, Emma Stone,...
# 8805    [Tim Allen, Courteney Cox, Chevy Chase, Kate M...
# 8806    [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...
# Name: cast, Length: 7982, dtype: object

# %%
lista_n = df_netflix["cast"].dropna().str.split(', ').values.tolist() # pasa a lista los valores

lista_n = [element for sublist in lista_n for element in sublist] # se aplana la lista

serie_n = pd.Series(lista_n)

print(serie_n.value_counts().to_frame())
# Out:
#                    count
# Anupam Kher           43
# Shah Rukh Khan        35
# Julie Tejwani         33
# Takahiro Sakurai      32
# Naseeruddin Shah      32
# ...                  ...
# Tejashree Pradhan      1
# Neha Joshi             1
# Ayesha Omer            1
# Samina Peerzada        1
# Waseem Abbas           1
#
# [36439 rows x 1 columns]
